# %% [markdown]
# ## 1. Project Title: Machine Learning for Jewellery Price Optimization

# %% [markdown]
# This project aims to successfully predict the prices of jewellery pieces. This will allow the jewellery company to reduce its dependence on gemologists and expensive jewellery appraisal experts.

# %% [markdown]
# ## 2. Methodology

# %% [markdown]
# This project will be carried out using the CRISP-DM (Cross Industry Standard Process for Data Mining) methodology.
# This is one of the most popular data science methodologies and is characterized by six important phases, which are as follows:
#
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Preparation
# 4. Data Modelling
# 5. Model Evaluation
# 6. Model Deployment
#
# It should be noted that these phases are usually recurrent in nature i.e some phases may be repeated.
# As such they do not really follow a linear progression.

# %% [markdown]
# ## 3. Tools

# %% [markdown]
# The tools of use for this project include:
#
# 1. Pandas - A python library built upon the Numpy library. Useful in Data wrangling and manipulation
# 2. Numpy - Usedin numerical operations
# 3. Matplotlib and Seaborn - Python libraries for train visualization. Other alternatives are Bokeh and Plotly
# 4. Sci-kit learn - Used extensively for Machine Learning.

# %% [markdown]
# # Project implementation using CRISP-DM

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Gemineye Emporium is an expanding jewelery dealer. The firm has recently begun a new wave of expansion acros the country.
# While this should be good for business, it also comes with increased costs and the need for increased operational efficiency.
#
# One such area is the need to accurately price their jewelery products. A t present, their jewelery items are being priced by gemologists and appraisal experts.
# However, this process can be quite a lengthy one, not to mention expensive, as most gemologists are well-sought and expensive to call upon. Gemineye would loveto explore the use
# of machine learning for predicting the optimal prices at which their jewelery should be sold. Utilizing ML for this task would allow the company:
#
#     1. improve the speed and scalability of their pricing process and
#     2. cut down on the costs of hiring gem experts.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# With the business understanding out of the way, the next step is to understand the data to be obtained and used for the task. This will involve the process of ExploratoryData Analysis(EDA).
#
# EDA is the process of sifting through data with the goal of extracting insights. These insights allow a better understanding of the available data and what can be done with it.
# They can also be used for guided preparation of the dataset in the appropriate manner. Just like regular analysis, EDA begins with a set of questions and/or hypotheses. The EDA process will then prove or disprove these hypotheses,
# and hopefully reveal other points of inquiry along the way.
#
# The required libraries and packages are imported first. The EDA process is carried out next. The high-level steps are as follows:
#
#     1. Import the required libraries
#     2. Load in the dataset
#     3. Analyze and observe its properties.
#        * Missing data
#        * Outliers
#        * Inconsistent values
#        * Low categorical cardinality
#        * Data imbalance
#        * Feature correlations
#     4. Report on these properties and how they might affect our final solution.

# %%
### Import the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Set visualization theme
sns.set()

# %%
### Import the dataset

data = pd.read_csv("Jewelry_Dataset.csv")

data.columns = [
    "Order_Datetime",
    "Order_ID",
    "Product_ID",
    "SKU_Quantity",
    "Category_ID",
    "Category",
    "Brand_ID",
    "Price_USD",
    "User_ID",
    "Target_Gender",
    "Main_Color",
    "Main_Metal",
    "Main_Gem",
]

# %%
### Peek the data
data.head()
# Out:
#             Order_Datetime             Order_ID           Product_ID  \
# 0  2018-12-01 17:38:31 UTC  1924899396621697920  1806829193678291446
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449
#
#    SKU_Quantity   Category_ID          Category  Brand_ID  Price_USD  \
# 0             1  1.806829e+18               NaN       NaN     212.14
# 1             1  1.806829e+18   jewelry.pendant       1.0      54.66
# 2             1  1.806829e+18   jewelry.pendant       0.0      88.90
# 3             1  1.806829e+18  jewelry.necklace       0.0     417.67
# 4             1  1.806829e+18   jewelry.earring       1.0     102.27
#
#         User_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 0  1.515916e+18           NaN     yellow       gold       NaN
# 1  1.515916e+18             f      white       gold  sapphire
# 2  1.515916e+18             f        red       gold   diamond
# 3  1.515916e+18           NaN        red       gold  amethyst
# 4  1.515916e+18           NaN        red       gold       NaN

# %%
data.shape
# Out:
# (95910, 13)

# %%
### check for Missing values
data.isnull().sum()
# Out:
# Order_Datetime        0
# Order_ID              0
# Product_ID            0
# SKU_Quantity          0
# Category_ID        5352
# Category           9933
# Brand_ID           4785
# Price_USD          5352
# User_ID            5352
# Target_Gender     48167
# Main_Color         7660
# Main_Metal         5462
# Main_Gem          34058
# dtype: int64

# %%
### Feature cardinality
data.nunique()
# Out:
# Order_Datetime    74504
# Order_ID          74759
# Product_ID         9613
# SKU_Quantity          1
# Category_ID          25
# Category            218
# Brand_ID           2537
# Price_USD          3166
# User_ID           31079
# Target_Gender         2
# Main_Color            5
# Main_Metal            3
# Main_Gem             30
# dtype: int64

# %%
### Data description

data.describe()
# Out:
#            Order_ID    Product_ID  SKU_Quantity   Category_ID      Brand_ID  \
# count  9.591000e+04  9.591000e+04       95910.0  9.055800e+04  9.112500e+04
# mean   2.485191e+18  1.815970e+18           1.0  1.805947e+18  8.891036e+16
# std    1.934750e+17  2.136814e+17           0.0  2.083954e+16  3.559651e+17
# min    1.924899e+18  1.313551e+18           1.0  1.313678e+18  0.000000e+00
# 25%    2.379732e+18  1.515966e+18           1.0  1.806829e+18  0.000000e+00
# 50%    2.524282e+18  1.956664e+18           1.0  1.806829e+18  1.000000e+00
# 75%    2.644347e+18  1.956664e+18           1.0  1.806829e+18  1.000000e+00
# max    2.719022e+18  2.541962e+18           1.0  1.806829e+18  1.550613e+18
#
#           Price_USD       User_ID
# count  90558.000000  9.055800e+04
# mean     362.213017  1.512644e+18
# std      444.157665  2.374776e+16
# min        0.990000  1.313554e+18
# 25%      145.620000  1.515916e+18
# 50%      258.770000  1.515916e+18
# 75%      431.370000  1.515916e+18
# max    34448.600000  1.554297e+18

# %%
#Data Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95910 entries, 0 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_Datetime  95910 non-null  object
#  1   Order_ID        95910 non-null  int64
#  2   Product_ID      95910 non-null  int64
#  3   SKU_Quantity    95910 non-null  int64
#  4   Category_ID     90558 non-null  float64
#  5   Category        85977 non-null  object
#  6   Brand_ID        91125 non-null  float64
#  7   Price_USD       90558 non-null  float64
#  8   User_ID         90558 non-null  float64
#  9   Target_Gender   47743 non-null  object
#  10  Main_Color      88250 non-null  object
#  11  Main_Metal      90448 non-null  object
#  12  Main_Gem        61852 non-null  object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 9.5+ MB

# %%
#Duplicate Values
num_duplicated = data.duplicated().sum()
num_duplicated
# Out:
# 2589

# %%
#Features with a cardinality of 1
invariant_features = data.nunique()[data.nunique()==1].index.tolist()
invariant_features
# Out:
# ['SKU_Quantity']

# %%
# Check for label distribution
data['Price_USD'].skew()
# Out:
# 18.95906072625981

# %%
# Visualize price distribution
plt.figure(figsize =(10,8))

sns.kdeplot(data=data, x = "Price_USD")
plt.xlabel("Price in USD")
plt.ylabel("Price Frequency")

plt.tight_layout()
plt.show();
plt.close()

# %% [markdown]
# Our data is positively skewed. The majority of the data points fall on the left side of the graph, with a longer tail stretching out towards the right side. This means that the  mean will be greater than the median in a positively skewed distribution.
# Most prices might fall in the middle range, with a smaller number of prices that could be from very wealthy individuals on the far right side (high earners).

# %%
data['Price_USD'].kurtosis()
# Out:
# 1054.8979068506155

# %%
#Target Gender analysis
data["Target_Gender"].value_counts()
# Out:
# f    47379
# m      364
# Name: Target_Gender, dtype: int64

# %%
#Target Gender analysis
data["Target_Gender"].value_counts(normalize = True)
# Out:
# f    0.992376
# m    0.007624
# Name: Target_Gender, dtype: float64

# %%
# Visualize Target Gender 
plt.figure(figsize = (10,8))

sns.countplot(data=data ,x = "Target_Gender")

plt.xlabel("Gender")
plt.ylabel("Gender Subpopulation")

plt.show();
plt.close()

# %%
#Jewelry category analysis
data['Category'].value_counts()
# Out:
# jewelry.earring     29051
# jewelry.ring        28300
# jewelry.pendant     13088
# jewelry.bracelet     6188
# 0.00                 4392
#                     ...
# 626.58                  1
# 13.42                   1
# 2.88                    1
# 101.23                  1
# 253.77                  1
# Name: Category, Length: 218, dtype: int64

# %%
data['Category'].unique()
# Out:
# array([nan, 'jewelry.pendant', 'jewelry.necklace', 'jewelry.earring',
#        'jewelry.ring', 'jewelry.brooch', 'jewelry.bracelet',
#        'electronics.clocks', 'jewelry.souvenir', '230.12', '202.36',
#        '1098.03', '321.78', '1128.62', '81.27', '34.25', '582.16',
#        '227.37', '234.22', '150.55', '131.82', '2123.15', '109.45',
#        '49.22', '472.47', '205.38', '2746.44', '51.08', '231.12', '76.97',
#        '3054.73', '184.90', '380.10', '357.49', '15.47', '135.33',
#        '719.75', '93.01', '177.95', 'jewelry.stud', '102.10', '595.75',
#        '469.56', '427.07', '53.62', '77.53', '1469.18', '355.27',
#        '184.89', '154.66', '300.58', '83.73', '271.19', '3294.21',
#        '278.04', '3626.26', '126.03', '283.52', '114.38', '89.04', '8.22',
#        '124.88', '89.73', '171.23', '136.93', '19.04', '158.77', '187.10',
#        '151.92', '1845.89', '87.23', '248.58', '596.48', '208.88',
#        '193.11', '169.84', '1447.68', '45.07', '136.85', '282.05',
#        '61.51', '210.21', '137.12', '147.81', '419.45', '825.27',
#        '300.16', '541.78', '308.74', '766.85', '410.82', '101.23', '2.88',
#        '1356.16', '13.42', '35.21', '134.79', '626.58', '13.70', '108.53',
#        '119.01', '7.40', '4.79', '153.97', '482.47', '427.36', '289.18',
#        '25.48', '1858.49', '21.70', '11.77', '198.89', '17.51', '574.66',
#        '1319.93', '393.05', '358.22', '2282.19', '114.93', '371.23',
#        '63.56', '88.77', '133.70', '117.81', '166.03', '130.41', '195.75',
#        '104.79', '228.59', '1686.93', '65.89', '242.19', '252.47',
#        '210.41', '363.42', '149.04', '157.95', '176.30', '160.96',
#        '316.30', '258.77', '268.36', '838.90', '250.96', '832.01',
#        '312.33', '318.71', '323.60', '205.34', '608.22', '343.84',
#        '598.22', '508.08', '245.67', '338.36', '75.21', '573.81',
#        '691.51', '476.68', '247.68', '286.71', '863.67', '236.58',
#        '644.66', '40.82', '1376.99', '1.23', '621.23', '3454.79', '65.62',
#        '59.73', '571.30', '70.96', '271.26', '958.84', '527.26', '271.16',
#        '284.66', '261.64', '493.01', '35.48', '446.16', '526.41',
#        '2517.08', '331.51', '312.88', '148.63', '451.21', '369.82',
#        '537.40', '231.51', '316.34', '451.10', '283.49', '787.67',
#        '131.92', '495.48', '5.48', '186.03', '484.49', '331.23', '133.85',
#        '323.70', '2635.07', '297.22', '0.00', '259.58', '108.33',
#        '4876.49', '308.08', '190.27', '916.44', '132.53', '1829.37',
#        '2208.90', '75.76', '278.01', '662.30', '253.77'], dtype=object)

# %%
#Extract the actual categories
categories = data['Category'].unique().tolist()
categories = [c for c in categories if isinstance(c, str) and 'jewelry' in c]

# %%
categories
# Out:
# ['jewelry.pendant',
#  'jewelry.necklace',
#  'jewelry.earring',
#  'jewelry.ring',
#  'jewelry.brooch',
#  'jewelry.bracelet',
#  'jewelry.souvenir',
#  'jewelry.stud']

# %%
# Pick out authentic data based on categories
real_categories = data.loc[data["Category"].isin(categories)]

# %%
# Check for the percentage of missing values
data.isnull().sum()/len(data) * 100
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_ID         0.000000
# SKU_Quantity       0.000000
# Category_ID        5.580231
# Category          10.356584
# Brand_ID           4.989052
# Price_USD          5.580231
# User_ID            5.580231
# Target_Gender     50.221041
# Main_Color         7.986654
# Main_Metal         5.694922
# Main_Gem          35.510374
# dtype: float64

# %%
# Check the percentage of the missing values based on the authentic category
real_categories.isnull().sum()/len(real_categories) * 100
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_ID         0.000000
# SKU_Quantity       0.000000
# Category_ID        0.000000
# Category           0.000000
# Brand_ID           4.309081
# Price_USD          0.000000
# User_ID            0.000000
# Target_Gender     44.842029
# Main_Color         2.656044
# Main_Metal         0.110617
# Main_Gem          24.232519
# dtype: float64

# %%
# Visualize jewelry categories
subdata = real_categories["Category"].value_counts()

jewelry_categories, counts = subdata.index.tolist(), subdata.values.tolist()

plt.figure(figsize =(10,8))

plt.pie(x = counts, labels =jewelry_categories)

plt.show();

# %%
# Category countplot

plt.figure(figsize =(15,8))

sns.countplot(data = real_categories, x = 'Category')

plt.xlabel("Jewelry categories")
plt.ylabel('Category frequency')

plt.show()

# %%
# Jewelry category by gender
plt.figure(figsize=(15,10))

sns.countplot(data = real_categories, x = 'Category', hue = 'Target_Gender')

plt.xlabel("Jewelry Category by Gender")
plt.ylabel("Frequency")
plt.show()

# %%
# Gender skew in original data
data['Target_Gender'].value_counts(normalize=True)
# Out:
# f    0.992376
# m    0.007624
# Name: Target_Gender, dtype: float64

# %%
# Gender skew in new data
real_categories['Target_Gender'].value_counts(normalize=True)
# Out:
# f    0.994434
# m    0.005566
# Name: Target_Gender, dtype: float64

# %%
encoded, category_code = pd.factorize(real_categories['Category'])
real_categories.loc[:, "Category"] = encoded
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\1110490584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_categories.loc[:, "Category"] = encoded
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\1110490584.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   real_categories.loc[:, "Category"] = encoded

# %%
encoded, category_code = pd.factorize(real_categories['Target_Gender'])
real_categories.loc[:, "Target_Gender"] = encoded
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\1781748120.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_categories.loc[:, "Target_Gender"] = encoded
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\1781748120.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   real_categories.loc[:, "Target_Gender"] = encoded

# %%
encoded, category_code = pd.factorize(real_categories['Main_Gem'])
real_categories.loc[:, "Main_Gem"] = encoded
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\3528211701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_categories.loc[:, "Main_Gem"] = encoded
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\3528211701.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   real_categories.loc[:, "Main_Gem"] = encoded

# %%
encoded, category_code = pd.factorize(real_categories['Main_Color'])
real_categories.loc[:, "Main_Color"] = encoded
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\2277587521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_categories.loc[:, "Main_Color"] = encoded
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\2277587521.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   real_categories.loc[:, "Main_Color"] = encoded

# %%
encoded, category_code = pd.factorize(real_categories['Main_Metal'])
real_categories.loc[:, "Main_Metal"] = encoded
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\3979828366.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_categories.loc[:, "Main_Metal"] = encoded
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2788\3979828366.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   real_categories.loc[:, "Main_Metal"] = encoded

# %%
real_categories.head()
# Out:
#             Order_Datetime             Order_ID           Product_ID  \
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449
# 5  2018-12-02 22:09:34 UTC  1925760595336888995  1600021442638905547
#
#    SKU_Quantity   Category_ID  Category  Brand_ID  Price_USD       User_ID  \
# 1             1  1.806829e+18         0       1.0      54.66  1.515916e+18
# 2             1  1.806829e+18         0       0.0      88.90  1.515916e+18
# 3             1  1.806829e+18         1       0.0     417.67  1.515916e+18
# 4             1  1.806829e+18         2       1.0     102.27  1.515916e+18
# 5             1  1.806829e+18         2       0.0     150.55  1.515916e+18
#
#    Target_Gender  Main_Color  Main_Metal  Main_Gem
# 1              0           0           0         0
# 2              0           1           0         1
# 3             -1           1           0         2
# 4             -1           1           0        -1
# 5             -1           1           0         1

# %%
real_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80458 entries, 1 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_Datetime  80458 non-null  object
#  1   Order_ID        80458 non-null  int64
#  2   Product_ID      80458 non-null  int64
#  3   SKU_Quantity    80458 non-null  int64
#  4   Category_ID     80458 non-null  float64
#  5   Category        80458 non-null  int64
#  6   Brand_ID        76991 non-null  float64
#  7   Price_USD       80458 non-null  float64
#  8   User_ID         80458 non-null  float64
#  9   Target_Gender   80458 non-null  int64
#  10  Main_Color      80458 non-null  int64
#  11  Main_Metal      80458 non-null  int64
#  12  Main_Gem        80458 non-null  int64
# dtypes: float64(4), int64(8), object(1)
# memory usage: 8.6+ MB

# %%
correlations = real_categories.drop(labels =["Order_Datetime", "User_ID", "Order_ID", "Product_ID"], axis = 1).corr(method = "spearman")

# %%
correlations
# Out:
#                SKU_Quantity  Category_ID  Category  Brand_ID  Price_USD  \
# SKU_Quantity            NaN          NaN       NaN       NaN        NaN
# Category_ID             NaN     1.000000 -0.886212  0.111328  -0.296495
# Category                NaN    -0.886212  1.000000 -0.111680   0.267257
# Brand_ID                NaN     0.111328 -0.111680  1.000000  -0.018428
# Price_USD               NaN    -0.296495  0.267257 -0.018428   1.000000
# Target_Gender           NaN     0.106286 -0.124101  0.623701   0.049532
# Main_Color              NaN     0.003396 -0.059402  0.100816   0.013177
# Main_Metal              NaN     0.157834  0.105056  0.003835  -0.173050
# Main_Gem                NaN     0.050483 -0.082944  0.076277  -0.006630
#
#                Target_Gender  Main_Color  Main_Metal  Main_Gem
# SKU_Quantity             NaN         NaN         NaN       NaN
# Category_ID         0.106286    0.003396    0.157834  0.050483
# Category           -0.124101   -0.059402    0.105056 -0.082944
# Brand_ID            0.623701    0.100816    0.003835  0.076277
# Price_USD           0.049532    0.013177   -0.173050 -0.006630
# Target_Gender       1.000000    0.056950   -0.046436  0.166125
# Main_Color          0.056950    1.000000   -0.238080  0.136232
# Main_Metal         -0.046436   -0.238080    1.000000 -0.055603
# Main_Gem            0.166125    0.136232   -0.055603  1.000000

# %%
plt.figure(figsize=(10,8))

sns.heatmap(correlations, annot = True, center = .3)
plt.show()

# %%
#Set correlation limits
upper = 1
lower = .2

# %%
correlated_columns = {
    column: correlations[(correlations[column]> lower) & (upper> correlations[column])].index.tolist()
    for column in correlations.columns
}

# %%
correlated_columns
# Out:
# {'SKU_Quantity': [],
#  'Category_ID': [],
#  'Category': ['Price_USD'],
#  'Brand_ID': ['Target_Gender'],
#  'Price_USD': ['Category'],
#  'Target_Gender': ['Brand_ID'],
#  'Main_Color': [],
#  'Main_Metal': [],
#  'Main_Gem': []}

# %% [markdown]
# ## 2.2 Data Implications

# %% [markdown]
# Implied by our findings above, we can say the following:
#
#     1. Missing values: There are a lot of missing values in the dataset. This may be fixed either by value imputations or encoding.
#
#     2. Data corruption: Some variables (e.g jewelry category) contain corrupt values.
#
#     3. Rare values: some features have some values that occur rarely. A prime instance of this is the Target Gender column,
#         where the male gender is rarely represented. Sometimes, these are data issues. Other times, like in this case can be a true reflection of the distribution from which the data is generated.
#
#     4. Low cardinality or feature invariance: The  SKU_Quantity feature only has one unique value(e.g 1). This fearure provides no new information.
#
#     5. Target skew: The target variable is highly right-skewed. This can present an issue during training.
#
#     6. Correlation: For the most part, the features exhibit low multicollinearity, hence ensuring feature independence.      However, the target variable exhibits a low corelation  with the independent variables.

# %% [markdown]
#  ## 03. Data Preparation

# %% [markdown]
# Based on the Data Implications discovered prior, the folowing steps will be experimented upon for the data preparation stage.
#
#     1. Missing values: The missing values will be treated via an algorithmic method. SimpleImputer.
#
#     2. Feature Encoding: The categorical features will be encoded.
#
#     3. Redundant Features: Certain features will be eliminated for a number of reasons. These are:
#
#         A. SKU_Quantity: Feature invariance
#
#         B. Order_ID: Simple identifier: has no real-world influence on jewelry price.
#
#         C. Product_ID:Same with Order_ID.
#
#         D. Order_Datetime: Avoid data leakage, would likely not be available in the real-world.
#
#     4. Target Skew: The target variable is strongly right-skewed. This can be an issue when learning a mapping from the data space to the label space. This issue will be fixed
#         using the TransformedTargetRegressor utility.
#
#     NOTE: Most of the data preparation steps will be carried out via the use of pipeline class from Sci-kit learn.
#     The pipeline object allows us to chain transformers and estimators sequentially for use as one composite object.
#
#     High level steps:
#
#       1. Eliminate less useful features.
#       2. Extract records with actual categories.
#       3. Encode categorical features(if required)
#       4. Account for target skew.
#       5. Fix missing values.

# %%
# Columns to eliminate

columns_to_eliminate = [
    "SKU_Quantity",
    "Order_ID",
    "Order_Datetime",
    "Product_ID",
    "User_ID",
    "Category_ID",
]

# %%
#Eliminate unused features
data.drop(labels = columns_to_eliminate, axis = 1, inplace = True)

# %%
data.head()
# Out:
#            Category  Brand_ID  Price_USD Target_Gender Main_Color Main_Metal  \
# 0               NaN       NaN     212.14           NaN     yellow       gold
# 1   jewelry.pendant       1.0      54.66             f      white       gold
# 2   jewelry.pendant       0.0      88.90             f        red       gold
# 3  jewelry.necklace       0.0     417.67           NaN        red       gold
# 4   jewelry.earring       1.0     102.27           NaN        red       gold
#
#    Main_Gem
# 0       NaN
# 1  sapphire
# 2   diamond
# 3  amethyst
# 4       NaN

# %%
# Eliminate unrealistic categories
data = data.loc[data["Category"].isin(categories), :]

# %%
data.shape
# Out:
# (80458, 7)

# %%
from sklearn.model_selection import train_test_split

# %%
# separate features from labels
X, y = data.drop(labels = ["Price_USD"], axis = 1), data["Price_USD"]

# %%
# Create test and train splits
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =.2)

# %% [markdown]
# ## 04. Data Modeling

# %% [markdown]
# 1. Linear Regression
# 2. Extremely Random Forest(ExtraTrees)
# 3. Adaptive Boosting(AdaBoost)
# 4. Catboost

# %% [markdown]
#   1. Encode categorical features(if required)
#   2. Account for target skew.
#   3. Fix missing values.

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder
from sklearn.compose import TransformedTargetRegressor, ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PowerTransformer

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor
from catboost import CatBoostRegressor

# %%
from sklearn.pipeline import Pipeline

# %%
def generate_pipeline(model, column_indices, categorical_indices,fill_missing = True, one_hot = True, label_encode = False):
    
    first_transformer = ColumnTransformer(
    transformers =  [
        ("imputer", SimpleImputer(strategy = "most_frequent"), column_indices)
    ],
    remainder = "passthrough",
    sparse_threshold = 0.
    )
    
    second_transformer = ColumnTransformer(
    transformers =  [
        ("one_hot", OneHotEncoder(), categorical_indices)
    ],
    remainder = "passthrough",
    sparse_threshold = 0.
    )
    
    third_transformer = ColumnTransformer(
    transformers =  [
        ("ordinal", OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), categorical_indices)
    ],
    remainder = "passthrough",
    sparse_threshold = 0.
    )
    
    steps = []
    
    if fill_missing:
        steps.append(("first", first_transformer))
        
    if label_encode:
        steps.append(("third", third_transformer))
        
    if one_hot:
        steps.append(("second", second_transformer))
        
    steps.append(("model", model ))
        
    model_pipe = Pipeline(steps = steps)
    
    return model_pipe

# %%
X.head()
# Out:
#            Category  Brand_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 1   jewelry.pendant       1.0             f      white       gold  sapphire
# 2   jewelry.pendant       0.0             f        red       gold   diamond
# 3  jewelry.necklace       0.0           NaN        red       gold  amethyst
# 4   jewelry.earring       1.0           NaN        red       gold       NaN
# 5   jewelry.earring       0.0           NaN        red       gold   diamond

# %%
# Generate indices
columns = X.columns.tolist()

column_indices = [columns.index(c) for c in columns]
categorical_features = [c for c in columns if c not in ["Brand_ID"]]
categorical_indices = [columns.index(c) for c in categorical_features]

# %%
categorical_indices
# Out:
# [0, 2, 3, 4, 5]

# %%
#Catboost pipeline
cat_pipe = generate_pipeline(
    CatBoostRegressor(loss_function = "RMSE", iterations = 10000, learning_rate = 0.1, one_hot_max_size = 2),
    column_indices,
    categorical_indices,
    fill_missing = False, one_hot = False, label_encode = True
)

# %%
#Linear Regression pipeline 
lin_pipe = generate_pipeline(
    LinearRegression(),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
ada_pipe = generate_pipeline(
    AdaBoostRegressor(loss = "exponential", n_estimators = 1000, learning_rate = .01),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
extra_pipe = generate_pipeline(
    ExtraTreesRegressor(criterion = "friedman_mse", n_estimators = 1000, bootstrap = True),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
 #Transform targets

cat_pipe = TransformedTargetRegressor(regressor = cat_pipe, transformer = PowerTransformer(method = "box-cox"))
lin_pipe = TransformedTargetRegressor(regressor = lin_pipe, transformer = PowerTransformer(method = "box-cox"))
ada_pipe = TransformedTargetRegressor(regressor = ada_pipe, transformer = PowerTransformer(method = "box-cox"))
extra_pipe = TransformedTargetRegressor(regressor = extra_pipe, transformer = PowerTransformer(method = "box-cox"))

# %%
y_train.head()
# Out:
# 78081     684.79
# 80579     766.99
# 37449     417.67
# 11039     205.34
# 8049     1027.26
# Name: Price_USD, dtype: float64

# %%
# Fit CatBoost
cat_pipe.fit(X_train, y_train).head()
# Out:
# 0:	learn: 0.9565669	total: 204ms	remaining: 33m 58s
# 1:	learn: 0.9199019	total: 235ms	remaining: 19m 32s
# 2:	learn: 0.8923350	total: 255ms	remaining: 14m 8s
# 3:	learn: 0.8661474	total: 270ms	remaining: 11m 14s
# 4:	learn: 0.8461764	total: 281ms	remaining: 9m 22s
# 5:	learn: 0.8292252	total: 293ms	remaining: 8m 7s
# 6:	learn: 0.8117995	total: 304ms	remaining: 7m 13s
# 7:	learn: 0.7996309	total: 314ms	remaining: 6m 32s
# 8:	learn: 0.7893651	total: 325ms	remaining: 6m
# 9:	learn: 0.7798827	total: 335ms	remaining: 5m 35s
# 10:	learn: 0.7709182	total: 347ms	remaining: 5m 14s
# 11:	learn: 0.7635299	total: 363ms	remaining: 5m 1s
# 12:	learn: 0.7546181	total: 376ms	remaining: 4m 49s
# 13:	learn: 0.7490487	total: 388ms	remaining: 4m 36s
# 14:	learn: 0.7444154	total: 399ms	remaining: 4m 25s
# 15:	learn: 0.7366858	total: 412ms	remaining: 4m 17s
# 16:	learn: 0.7302932	total: 427ms	remaining: 4m 10s
# 17:	learn: 0.7258072	total: 442ms	remaining: 4m 5s
# 18:	learn: 0.7218692	total: 453ms	remaining: 3m 57s
# 19:	learn: 0.7175354	total: 465ms	remaining: 3m 52s
# 20:	learn: 0.7142757	total: 476ms	remaining: 3m 46s
# 21:	learn: 0.7114475	total: 487ms	remaining: 3m 40s
# 22:	learn: 0.7095797	total: 497ms	remaining: 3m 35s
# 23:	learn: 0.7062046	total: 509ms	remaining: 3m 31s
# 24:	learn: 0.7048090	total: 520ms	remaining: 3m 27s
# 25:	learn: 0.7021919	total: 531ms	remaining: 3m 23s
# 26:	learn: 0.7006701	total: 542ms	remaining: 3m 20s
# 27:	learn: 0.6985508	total: 553ms	remaining: 3m 16s
# 28:	learn: 0.6973111	total: 563ms	remaining: 3m 13s
# 29:	learn: 0.6954623	total: 577ms	remaining: 3m 11s
# 30:	learn: 0.6938213	total: 589ms	remaining: 3m 9s
# 31:	learn: 0.6924348	total: 601ms	remaining: 3m 7s
# 32:	learn: 0.6905834	total: 613ms	remaining: 3m 5s
# 33:	learn: 0.6894587	total: 627ms	remaining: 3m 3s
# 34:	learn: 0.6876642	total: 642ms	remaining: 3m 2s
# 35:	learn: 0.6867657	total: 653ms	remaining: 3m
# 36:	learn: 0.6856957	total: 664ms	remaining: 2m 58s
# 37:	learn: 0.6845087	total: 675ms	remaining: 2m 56s
# 38:	learn: 0.6836185	total: 685ms	remaining: 2m 55s
# 39:	learn: 0.6828883	total: 695ms	remaining: 2m 53s
# 40:	learn: 0.6812024	total: 706ms	remaining: 2m 51s
# 41:	learn: 0.6804703	total: 716ms	remaining: 2m 49s
# 42:	learn: 0.6795136	total: 727ms	remaining: 2m 48s
# 43:	learn: 0.6789843	total: 737ms	remaining: 2m 46s
# 44:	learn: 0.6785689	total: 746ms	remaining: 2m 45s
# 45:	learn: 0.6778634	total: 757ms	remaining: 2m 43s
# 46:	learn: 0.6770648	total: 767ms	remaining: 2m 42s
# 47:	learn: 0.6763608	total: 777ms	remaining: 2m 41s
# 48:	learn: 0.6756653	total: 789ms	remaining: 2m 40s
# 49:	learn: 0.6751490	total: 800ms	remaining: 2m 39s
# 50:	learn: 0.6745800	total: 811ms	remaining: 2m 38s
# 51:	learn: 0.6739449	total: 825ms	remaining: 2m 37s
# 52:	learn: 0.6727993	total: 840ms	remaining: 2m 37s
# 53:	learn: 0.6719996	total: 852ms	remaining: 2m 36s
# 54:	learn: 0.6713107	total: 863ms	remaining: 2m 36s
# 55:	learn: 0.6708891	total: 873ms	remaining: 2m 35s
# 56:	learn: 0.6702474	total: 885ms	remaining: 2m 34s
# 57:	learn: 0.6690456	total: 895ms	remaining: 2m 33s
# 58:	learn: 0.6688233	total: 905ms	remaining: 2m 32s
# 59:	learn: 0.6684194	total: 915ms	remaining: 2m 31s
# 60:	learn: 0.6681156	total: 926ms	remaining: 2m 30s
# 61:	learn: 0.6676892	total: 937ms	remaining: 2m 30s
# 62:	learn: 0.6675421	total: 946ms	remaining: 2m 29s
# 63:	learn: 0.6671030	total: 957ms	remaining: 2m 28s
# 64:	learn: 0.6669134	total: 967ms	remaining: 2m 27s
# 65:	learn: 0.6665588	total: 977ms	remaining: 2m 27s
# 66:	learn: 0.6662616	total: 988ms	remaining: 2m 26s
# 67:	learn: 0.6656913	total: 998ms	remaining: 2m 25s
# 68:	learn: 0.6655343	total: 1.01s	remaining: 2m 25s
# 69:	learn: 0.6653551	total: 1.02s	remaining: 2m 24s
# 70:	learn: 0.6652412	total: 1.03s	remaining: 2m 24s
# 71:	learn: 0.6648500	total: 1.04s	remaining: 2m 24s
# 72:	learn: 0.6641472	total: 1.06s	remaining: 2m 23s
# 73:	learn: 0.6639455	total: 1.07s	remaining: 2m 23s
# 74:	learn: 0.6635033	total: 1.08s	remaining: 2m 22s
# 75:	learn: 0.6631410	total: 1.09s	remaining: 2m 22s
# 76:	learn: 0.6626408	total: 1.1s	remaining: 2m 21s
# 77:	learn: 0.6623649	total: 1.11s	remaining: 2m 21s
# 78:	learn: 0.6620295	total: 1.12s	remaining: 2m 20s
# 79:	learn: 0.6616851	total: 1.13s	remaining: 2m 20s
# 80:	learn: 0.6614277	total: 1.14s	remaining: 2m 19s
# 81:	learn: 0.6611881	total: 1.15s	remaining: 2m 19s
# 82:	learn: 0.6607800	total: 1.16s	remaining: 2m 18s
# 83:	learn: 0.6605975	total: 1.17s	remaining: 2m 18s
# 84:	learn: 0.6603901	total: 1.18s	remaining: 2m 17s
# 85:	learn: 0.6597620	total: 1.19s	remaining: 2m 17s
# 86:	learn: 0.6594615	total: 1.2s	remaining: 2m 17s
# 87:	learn: 0.6589914	total: 1.22s	remaining: 2m 17s
# 88:	learn: 0.6581461	total: 1.23s	remaining: 2m 17s
# 89:	learn: 0.6580434	total: 1.25s	remaining: 2m 17s
# 90:	learn: 0.6578700	total: 1.26s	remaining: 2m 16s
# 91:	learn: 0.6573585	total: 1.27s	remaining: 2m 16s
# 92:	learn: 0.6572615	total: 1.28s	remaining: 2m 15s
# 93:	learn: 0.6570211	total: 1.29s	remaining: 2m 15s
# 94:	learn: 0.6565078	total: 1.3s	remaining: 2m 15s
# 95:	learn: 0.6562831	total: 1.31s	remaining: 2m 14s
# 96:	learn: 0.6559361	total: 1.32s	remaining: 2m 14s
# 97:	learn: 0.6558544	total: 1.33s	remaining: 2m 14s
# 98:	learn: 0.6557040	total: 1.34s	remaining: 2m 13s
# 99:	learn: 0.6555740	total: 1.35s	remaining: 2m 13s
# 100:	learn: 0.6551815	total: 1.36s	remaining: 2m 13s
# 101:	learn: 0.6550475	total: 1.37s	remaining: 2m 12s
# 102:	learn: 0.6545968	total: 1.38s	remaining: 2m 12s
# 103:	learn: 0.6543713	total: 1.39s	remaining: 2m 12s
# 104:	learn: 0.6538742	total: 1.4s	remaining: 2m 11s
# 105:	learn: 0.6538018	total: 1.41s	remaining: 2m 11s
# 106:	learn: 0.6536945	total: 1.42s	remaining: 2m 11s
# 107:	learn: 0.6533564	total: 1.43s	remaining: 2m 11s
# 108:	learn: 0.6531955	total: 1.45s	remaining: 2m 11s
# 109:	learn: 0.6527855	total: 1.46s	remaining: 2m 11s
# 110:	learn: 0.6525457	total: 1.51s	remaining: 2m 14s
# 111:	learn: 0.6524773	total: 1.52s	remaining: 2m 14s
# 112:	learn: 0.6522361	total: 1.53s	remaining: 2m 14s
# 113:	learn: 0.6521685	total: 1.54s	remaining: 2m 13s
# 114:	learn: 0.6520391	total: 1.55s	remaining: 2m 13s
# 115:	learn: 0.6517347	total: 1.56s	remaining: 2m 13s
# 116:	learn: 0.6515726	total: 1.58s	remaining: 2m 13s
# 117:	learn: 0.6514222	total: 1.58s	remaining: 2m 12s
# 118:	learn: 0.6512710	total: 1.59s	remaining: 2m 12s
# 119:	learn: 0.6508941	total: 1.61s	remaining: 2m 12s
# 120:	learn: 0.6506684	total: 1.62s	remaining: 2m 12s
# 121:	learn: 0.6505273	total: 1.63s	remaining: 2m 11s
# 122:	learn: 0.6504218	total: 1.64s	remaining: 2m 11s
# 123:	learn: 0.6502295	total: 1.65s	remaining: 2m 11s
# 124:	learn: 0.6498386	total: 1.66s	remaining: 2m 11s
# 125:	learn: 0.6497184	total: 1.68s	remaining: 2m 11s
# 126:	learn: 0.6493995	total: 1.69s	remaining: 2m 11s
# 127:	learn: 0.6491790	total: 1.7s	remaining: 2m 11s
# 128:	learn: 0.6489756	total: 1.71s	remaining: 2m 10s
# 129:	learn: 0.6485796	total: 1.72s	remaining: 2m 10s
# 130:	learn: 0.6484398	total: 1.73s	remaining: 2m 10s
# 131:	learn: 0.6482920	total: 1.74s	remaining: 2m 10s
# 132:	learn: 0.6481094	total: 1.75s	remaining: 2m 9s
# 133:	learn: 0.6479161	total: 1.76s	remaining: 2m 9s
# 134:	learn: 0.6476997	total: 1.77s	remaining: 2m 9s
# 135:	learn: 0.6475808	total: 1.78s	remaining: 2m 9s
# 136:	learn: 0.6473897	total: 1.79s	remaining: 2m 9s
# 137:	learn: 0.6472086	total: 1.8s	remaining: 2m 8s
# 138:	learn: 0.6470901	total: 1.81s	remaining: 2m 8s
# 139:	learn: 0.6468826	total: 1.82s	remaining: 2m 8s
# 140:	learn: 0.6467709	total: 1.83s	remaining: 2m 8s
# 141:	learn: 0.6465876	total: 1.85s	remaining: 2m 8s
# 142:	learn: 0.6464334	total: 1.86s	remaining: 2m 8s
# 143:	learn: 0.6463349	total: 1.87s	remaining: 2m 8s
# 144:	learn: 0.6461665	total: 1.88s	remaining: 2m 7s
# 145:	learn: 0.6459001	total: 1.89s	remaining: 2m 7s
# 146:	learn: 0.6457493	total: 1.9s	remaining: 2m 7s
# 147:	learn: 0.6455656	total: 1.92s	remaining: 2m 7s
# 148:	learn: 0.6453310	total: 1.93s	remaining: 2m 7s
# 149:	learn: 0.6452582	total: 1.94s	remaining: 2m 7s
# 150:	learn: 0.6451001	total: 1.95s	remaining: 2m 6s
# 151:	learn: 0.6450347	total: 1.96s	remaining: 2m 6s
# 152:	learn: 0.6449794	total: 1.97s	remaining: 2m 6s
# 153:	learn: 0.6447472	total: 1.98s	remaining: 2m 6s
# 154:	learn: 0.6446583	total: 1.99s	remaining: 2m 6s
# 155:	learn: 0.6445420	total: 2s	remaining: 2m 5s
# 156:	learn: 0.6444158	total: 2.01s	remaining: 2m 5s
# 157:	learn: 0.6443263	total: 2.02s	remaining: 2m 5s
# 158:	learn: 0.6442573	total: 2.03s	remaining: 2m 5s
# 159:	learn: 0.6440039	total: 2.04s	remaining: 2m 5s
# 160:	learn: 0.6439156	total: 2.05s	remaining: 2m 5s
# 161:	learn: 0.6435826	total: 2.06s	remaining: 2m 5s
# 162:	learn: 0.6434310	total: 2.08s	remaining: 2m 5s
# 163:	learn: 0.6433837	total: 2.09s	remaining: 2m 5s
# 164:	learn: 0.6432964	total: 2.1s	remaining: 2m 5s
# 165:	learn: 0.6431543	total: 2.11s	remaining: 2m 4s
# 166:	learn: 0.6430168	total: 2.12s	remaining: 2m 4s
# 167:	learn: 0.6429881	total: 2.13s	remaining: 2m 4s
# 168:	learn: 0.6429082	total: 2.14s	remaining: 2m 4s
# 169:	learn: 0.6428192	total: 2.15s	remaining: 2m 4s
# 170:	learn: 0.6427651	total: 2.16s	remaining: 2m 4s
# 171:	learn: 0.6426926	total: 2.17s	remaining: 2m 4s
# 172:	learn: 0.6425043	total: 2.18s	remaining: 2m 3s
# 173:	learn: 0.6423667	total: 2.19s	remaining: 2m 3s
# 174:	learn: 0.6422810	total: 2.2s	remaining: 2m 3s
# 175:	learn: 0.6421199	total: 2.21s	remaining: 2m 3s
# 176:	learn: 0.6420364	total: 2.22s	remaining: 2m 3s
# 177:	learn: 0.6419412	total: 2.23s	remaining: 2m 3s
# 178:	learn: 0.6418723	total: 2.24s	remaining: 2m 3s
# 179:	learn: 0.6418097	total: 2.25s	remaining: 2m 2s
# 180:	learn: 0.6417781	total: 2.26s	remaining: 2m 2s
# 181:	learn: 0.6417218	total: 2.27s	remaining: 2m 2s
# 182:	learn: 0.6415994	total: 2.29s	remaining: 2m 2s
# 183:	learn: 0.6414878	total: 2.3s	remaining: 2m 2s
# 184:	learn: 0.6414384	total: 2.31s	remaining: 2m 2s
# 185:	learn: 0.6413799	total: 2.32s	remaining: 2m 2s
# 186:	learn: 0.6412809	total: 2.33s	remaining: 2m 2s
# 187:	learn: 0.6412635	total: 2.34s	remaining: 2m 2s
# 188:	learn: 0.6411825	total: 2.35s	remaining: 2m 2s
# 189:	learn: 0.6411601	total: 2.36s	remaining: 2m 1s
# 190:	learn: 0.6411168	total: 2.37s	remaining: 2m 1s
# 191:	learn: 0.6410666	total: 2.38s	remaining: 2m 1s
# 192:	learn: 0.6410400	total: 2.39s	remaining: 2m 1s
# 193:	learn: 0.6409735	total: 2.4s	remaining: 2m 1s
# 194:	learn: 0.6409278	total: 2.41s	remaining: 2m 1s
# 195:	learn: 0.6408774	total: 2.42s	remaining: 2m 1s
# 196:	learn: 0.6407588	total: 2.43s	remaining: 2m
# 197:	learn: 0.6406861	total: 2.44s	remaining: 2m
# 198:	learn: 0.6406081	total: 2.45s	remaining: 2m
# 199:	learn: 0.6403855	total: 2.46s	remaining: 2m
# 200:	learn: 0.6403437	total: 2.47s	remaining: 2m
# 201:	learn: 0.6403167	total: 2.48s	remaining: 2m
# 202:	learn: 0.6402011	total: 2.5s	remaining: 2m
# 203:	learn: 0.6401284	total: 2.51s	remaining: 2m
# 204:	learn: 0.6399391	total: 2.52s	remaining: 2m
# 205:	learn: 0.6398236	total: 2.53s	remaining: 2m
# 206:	learn: 0.6395238	total: 2.54s	remaining: 2m
# 207:	learn: 0.6394900	total: 2.55s	remaining: 2m
# 208:	learn: 0.6394452	total: 2.56s	remaining: 2m
# 209:	learn: 0.6394000	total: 2.57s	remaining: 1m 59s
# 210:	learn: 0.6393843	total: 2.58s	remaining: 1m 59s
# 211:	learn: 0.6393146	total: 2.59s	remaining: 1m 59s
# 212:	learn: 0.6390263	total: 2.6s	remaining: 1m 59s
# 213:	learn: 0.6389090	total: 2.61s	remaining: 1m 59s
# 214:	learn: 0.6388175	total: 2.62s	remaining: 1m 59s
# 215:	learn: 0.6386802	total: 2.63s	remaining: 1m 59s
# 216:	learn: 0.6385294	total: 2.65s	remaining: 1m 59s
# 217:	learn: 0.6384748	total: 2.65s	remaining: 1m 59s
# 218:	learn: 0.6384122	total: 2.67s	remaining: 1m 59s
# 219:	learn: 0.6383722	total: 2.68s	remaining: 1m 59s
# 220:	learn: 0.6383198	total: 2.69s	remaining: 1m 59s
# 221:	learn: 0.6382633	total: 2.7s	remaining: 1m 59s
# 222:	learn: 0.6381366	total: 2.71s	remaining: 1m 59s
# 223:	learn: 0.6380861	total: 2.73s	remaining: 1m 58s
# 224:	learn: 0.6380259	total: 2.73s	remaining: 1m 58s
# 225:	learn: 0.6379263	total: 2.75s	remaining: 1m 58s
# 226:	learn: 0.6378852	total: 2.76s	remaining: 1m 58s
# 227:	learn: 0.6378319	total: 2.77s	remaining: 1m 58s
# 228:	learn: 0.6377488	total: 2.78s	remaining: 1m 58s
# 229:	learn: 0.6376625	total: 2.79s	remaining: 1m 58s
# 230:	learn: 0.6375589	total: 2.8s	remaining: 1m 58s
# 231:	learn: 0.6374923	total: 2.81s	remaining: 1m 58s
# 232:	learn: 0.6374453	total: 2.82s	remaining: 1m 58s
# 233:	learn: 0.6374033	total: 2.83s	remaining: 1m 58s
# 234:	learn: 0.6373899	total: 2.84s	remaining: 1m 58s
# 235:	learn: 0.6373670	total: 2.85s	remaining: 1m 58s
# 236:	learn: 0.6372730	total: 2.87s	remaining: 1m 58s
# 237:	learn: 0.6371790	total: 2.88s	remaining: 1m 58s
# 238:	learn: 0.6371359	total: 2.89s	remaining: 1m 58s
# 239:	learn: 0.6371058	total: 2.91s	remaining: 1m 58s
# 240:	learn: 0.6370654	total: 2.92s	remaining: 1m 58s
# 241:	learn: 0.6369311	total: 2.95s	remaining: 1m 58s
# 242:	learn: 0.6368526	total: 2.96s	remaining: 1m 59s
# 243:	learn: 0.6368043	total: 2.98s	remaining: 1m 59s
# 244:	learn: 0.6367844	total: 2.99s	remaining: 1m 59s
# 245:	learn: 0.6367547	total: 3.01s	remaining: 1m 59s
# 246:	learn: 0.6366578	total: 3.02s	remaining: 1m 59s
# 247:	learn: 0.6366514	total: 3.04s	remaining: 1m 59s
# 248:	learn: 0.6364748	total: 3.06s	remaining: 1m 59s
# 249:	learn: 0.6364312	total: 3.07s	remaining: 1m 59s
# 250:	learn: 0.6363429	total: 3.08s	remaining: 1m 59s
# 251:	learn: 0.6362593	total: 3.1s	remaining: 2m
# 252:	learn: 0.6362208	total: 3.12s	remaining: 2m
# 253:	learn: 0.6361418	total: 3.14s	remaining: 2m
# 254:	learn: 0.6361087	total: 3.16s	remaining: 2m
# 255:	learn: 0.6358282	total: 3.17s	remaining: 2m
# 256:	learn: 0.6356414	total: 3.19s	remaining: 2m
# 257:	learn: 0.6355815	total: 3.21s	remaining: 2m 1s
# 258:	learn: 0.6353925	total: 3.22s	remaining: 2m 1s
# 259:	learn: 0.6353221	total: 3.24s	remaining: 2m 1s
# 260:	learn: 0.6352902	total: 3.26s	remaining: 2m 1s
# 261:	learn: 0.6352476	total: 3.27s	remaining: 2m 1s
# 262:	learn: 0.6351495	total: 3.29s	remaining: 2m 1s
# 263:	learn: 0.6350914	total: 3.3s	remaining: 2m 1s
# 264:	learn: 0.6350758	total: 3.32s	remaining: 2m 2s
# 265:	learn: 0.6350224	total: 3.34s	remaining: 2m 2s
# 266:	learn: 0.6350071	total: 3.35s	remaining: 2m 2s
# 267:	learn: 0.6349926	total: 3.37s	remaining: 2m 2s
# 268:	learn: 0.6349283	total: 3.39s	remaining: 2m 2s
# 269:	learn: 0.6347963	total: 3.4s	remaining: 2m 2s
# 270:	learn: 0.6347591	total: 3.42s	remaining: 2m 2s
# 271:	learn: 0.6347189	total: 3.43s	remaining: 2m 2s
# 272:	learn: 0.6346794	total: 3.45s	remaining: 2m 2s
# 273:	learn: 0.6346321	total: 3.46s	remaining: 2m 2s
# 274:	learn: 0.6345964	total: 3.48s	remaining: 2m 2s
# 275:	learn: 0.6345446	total: 3.49s	remaining: 2m 3s
# 276:	learn: 0.6344973	total: 3.51s	remaining: 2m 3s
# 277:	learn: 0.6344530	total: 3.52s	remaining: 2m 3s
# 278:	learn: 0.6344391	total: 3.54s	remaining: 2m 3s
# 279:	learn: 0.6343975	total: 3.55s	remaining: 2m 3s
# 280:	learn: 0.6343741	total: 3.57s	remaining: 2m 3s
# 281:	learn: 0.6343291	total: 3.58s	remaining: 2m 3s
# 282:	learn: 0.6343094	total: 3.6s	remaining: 2m 3s
# 283:	learn: 0.6342635	total: 3.61s	remaining: 2m 3s
# 284:	learn: 0.6342454	total: 3.63s	remaining: 2m 3s
# 285:	learn: 0.6340621	total: 3.64s	remaining: 2m 3s
# 286:	learn: 0.6340332	total: 3.65s	remaining: 2m 3s
# 287:	learn: 0.6340079	total: 3.67s	remaining: 2m 3s
# 288:	learn: 0.6339475	total: 3.68s	remaining: 2m 3s
# 289:	learn: 0.6339205	total: 3.69s	remaining: 2m 3s
# 290:	learn: 0.6338690	total: 3.7s	remaining: 2m 3s
# 291:	learn: 0.6338393	total: 3.71s	remaining: 2m 3s
# 292:	learn: 0.6338003	total: 3.72s	remaining: 2m 3s
# 293:	learn: 0.6337901	total: 3.73s	remaining: 2m 3s
# 294:	learn: 0.6336701	total: 3.74s	remaining: 2m 3s
# 295:	learn: 0.6335846	total: 3.75s	remaining: 2m 3s
# 296:	learn: 0.6335513	total: 3.77s	remaining: 2m 3s
# 297:	learn: 0.6335100	total: 3.78s	remaining: 2m 3s
# 298:	learn: 0.6334624	total: 3.79s	remaining: 2m 3s
# 299:	learn: 0.6333997	total: 3.8s	remaining: 2m 2s
# 300:	learn: 0.6332049	total: 3.81s	remaining: 2m 2s
# 301:	learn: 0.6331439	total: 3.82s	remaining: 2m 2s
# 302:	learn: 0.6330720	total: 3.83s	remaining: 2m 2s
# 303:	learn: 0.6329223	total: 3.85s	remaining: 2m 2s
# 304:	learn: 0.6328079	total: 3.86s	remaining: 2m 2s
# 305:	learn: 0.6326603	total: 3.87s	remaining: 2m 2s
# 306:	learn: 0.6325371	total: 3.88s	remaining: 2m 2s
# 307:	learn: 0.6323142	total: 3.89s	remaining: 2m 2s
# 308:	learn: 0.6322290	total: 3.9s	remaining: 2m 2s
# 309:	learn: 0.6321401	total: 3.91s	remaining: 2m 2s
# 310:	learn: 0.6321016	total: 3.92s	remaining: 2m 2s
# 311:	learn: 0.6320315	total: 3.93s	remaining: 2m 2s
# 312:	learn: 0.6320038	total: 3.94s	remaining: 2m 2s
# 313:	learn: 0.6319759	total: 3.95s	remaining: 2m 1s
# 314:	learn: 0.6318339	total: 3.97s	remaining: 2m 1s
# 315:	learn: 0.6316931	total: 3.98s	remaining: 2m 1s
# 316:	learn: 0.6316773	total: 3.99s	remaining: 2m 2s
# 317:	learn: 0.6316001	total: 4.01s	remaining: 2m 1s
# 318:	learn: 0.6315313	total: 4.02s	remaining: 2m 1s
# 319:	learn: 0.6314315	total: 4.03s	remaining: 2m 1s
# 320:	learn: 0.6313436	total: 4.04s	remaining: 2m 1s
# 321:	learn: 0.6312903	total: 4.05s	remaining: 2m 1s
# 322:	learn: 0.6312316	total: 4.06s	remaining: 2m 1s
# 323:	learn: 0.6312112	total: 4.07s	remaining: 2m 1s
# 324:	learn: 0.6311601	total: 4.08s	remaining: 2m 1s
# 325:	learn: 0.6311117	total: 4.09s	remaining: 2m 1s
# 326:	learn: 0.6310389	total: 4.1s	remaining: 2m 1s
# 327:	learn: 0.6309715	total: 4.12s	remaining: 2m 1s
# 328:	learn: 0.6309532	total: 4.13s	remaining: 2m 1s
# 329:	learn: 0.6309049	total: 4.14s	remaining: 2m 1s
# 330:	learn: 0.6308645	total: 4.15s	remaining: 2m 1s
# 331:	learn: 0.6307557	total: 4.16s	remaining: 2m 1s
# 332:	learn: 0.6307310	total: 4.17s	remaining: 2m 1s
# 333:	learn: 0.6306681	total: 4.19s	remaining: 2m 1s
# 334:	learn: 0.6306554	total: 4.2s	remaining: 2m 1s
# 335:	learn: 0.6306457	total: 4.21s	remaining: 2m 1s
# 336:	learn: 0.6306143	total: 4.23s	remaining: 2m 1s
# 337:	learn: 0.6306007	total: 4.24s	remaining: 2m 1s
# 338:	learn: 0.6305683	total: 4.26s	remaining: 2m 1s
# 339:	learn: 0.6305174	total: 4.28s	remaining: 2m 1s
# 340:	learn: 0.6304611	total: 4.29s	remaining: 2m 1s
# 341:	learn: 0.6303918	total: 4.31s	remaining: 2m 1s
# 342:	learn: 0.6303150	total: 4.32s	remaining: 2m 1s
# 343:	learn: 0.6302947	total: 4.34s	remaining: 2m 1s
# 344:	learn: 0.6302622	total: 4.35s	remaining: 2m 1s
# 345:	learn: 0.6302515	total: 4.37s	remaining: 2m 1s
# 346:	learn: 0.6301939	total: 4.38s	remaining: 2m 1s
# 347:	learn: 0.6301504	total: 4.4s	remaining: 2m 2s
# 348:	learn: 0.6301268	total: 4.42s	remaining: 2m 2s
# 349:	learn: 0.6300990	total: 4.44s	remaining: 2m 2s
# 350:	learn: 0.6300823	total: 4.45s	remaining: 2m 2s
# 351:	learn: 0.6299952	total: 4.47s	remaining: 2m 2s
# 352:	learn: 0.6299709	total: 4.49s	remaining: 2m 2s
# 353:	learn: 0.6299565	total: 4.5s	remaining: 2m 2s
# 354:	learn: 0.6299487	total: 4.51s	remaining: 2m 2s
# 355:	learn: 0.6299279	total: 4.53s	remaining: 2m 2s
# 356:	learn: 0.6299103	total: 4.54s	remaining: 2m 2s
# 357:	learn: 0.6298661	total: 4.56s	remaining: 2m 2s
# 358:	learn: 0.6298478	total: 4.57s	remaining: 2m 2s
# 359:	learn: 0.6297978	total: 4.58s	remaining: 2m 2s
# 360:	learn: 0.6297845	total: 4.6s	remaining: 2m 2s
# 361:	learn: 0.6297359	total: 4.61s	remaining: 2m 2s
# 362:	learn: 0.6297035	total: 4.63s	remaining: 2m 2s
# 363:	learn: 0.6296891	total: 4.64s	remaining: 2m 2s
# 364:	learn: 0.6295990	total: 4.66s	remaining: 2m 3s
# 365:	learn: 0.6295337	total: 4.67s	remaining: 2m 3s
# 366:	learn: 0.6294557	total: 4.69s	remaining: 2m 3s
# 367:	learn: 0.6293844	total: 4.71s	remaining: 2m 3s
# 368:	learn: 0.6293316	total: 4.72s	remaining: 2m 3s
# 369:	learn: 0.6292814	total: 4.74s	remaining: 2m 3s
# 370:	learn: 0.6292536	total: 4.76s	remaining: 2m 3s
# 371:	learn: 0.6292340	total: 4.77s	remaining: 2m 3s
# 372:	learn: 0.6292176	total: 4.79s	remaining: 2m 3s
# 373:	learn: 0.6291020	total: 4.8s	remaining: 2m 3s
# 374:	learn: 0.6289742	total: 4.82s	remaining: 2m 3s
# 375:	learn: 0.6288660	total: 4.84s	remaining: 2m 3s
# 376:	learn: 0.6288498	total: 4.86s	remaining: 2m 3s
# 377:	learn: 0.6287528	total: 4.87s	remaining: 2m 4s
# 378:	learn: 0.6286712	total: 4.89s	remaining: 2m 4s
# 379:	learn: 0.6286341	total: 4.91s	remaining: 2m 4s
# 380:	learn: 0.6286242	total: 4.92s	remaining: 2m 4s
# 381:	learn: 0.6285908	total: 4.93s	remaining: 2m 4s
# 382:	learn: 0.6284746	total: 4.95s	remaining: 2m 4s
# 383:	learn: 0.6284376	total: 4.97s	remaining: 2m 4s
# 384:	learn: 0.6283878	total: 4.99s	remaining: 2m 4s
# 385:	learn: 0.6283531	total: 5s	remaining: 2m 4s
# 386:	learn: 0.6282781	total: 5.02s	remaining: 2m 4s
# 387:	learn: 0.6281774	total: 5.04s	remaining: 2m 4s
# 388:	learn: 0.6281015	total: 5.06s	remaining: 2m 5s
# 389:	learn: 0.6280857	total: 5.08s	remaining: 2m 5s
# 390:	learn: 0.6279787	total: 5.1s	remaining: 2m 5s
# 391:	learn: 0.6279000	total: 5.11s	remaining: 2m 5s
# 392:	learn: 0.6278510	total: 5.13s	remaining: 2m 5s
# 393:	learn: 0.6278246	total: 5.14s	remaining: 2m 5s
# 394:	learn: 0.6277922	total: 5.15s	remaining: 2m 5s
# 395:	learn: 0.6277610	total: 5.16s	remaining: 2m 5s
# 396:	learn: 0.6276754	total: 5.18s	remaining: 2m 5s
# 397:	learn: 0.6276357	total: 5.19s	remaining: 2m 5s
# 398:	learn: 0.6276328	total: 5.2s	remaining: 2m 5s
# 399:	learn: 0.6275476	total: 5.21s	remaining: 2m 5s
# 400:	learn: 0.6275220	total: 5.22s	remaining: 2m 5s
# 401:	learn: 0.6274599	total: 5.24s	remaining: 2m 5s
# 402:	learn: 0.6274487	total: 5.25s	remaining: 2m 5s
# 403:	learn: 0.6274064	total: 5.26s	remaining: 2m 5s
# 404:	learn: 0.6273536	total: 5.27s	remaining: 2m 4s
# 405:	learn: 0.6273305	total: 5.28s	remaining: 2m 4s
# 406:	learn: 0.6273178	total: 5.29s	remaining: 2m 4s
# 407:	learn: 0.6272600	total: 5.3s	remaining: 2m 4s
# 408:	learn: 0.6272488	total: 5.32s	remaining: 2m 4s
# 409:	learn: 0.6272049	total: 5.33s	remaining: 2m 4s
# 410:	learn: 0.6271738	total: 5.34s	remaining: 2m 4s
# 411:	learn: 0.6271595	total: 5.35s	remaining: 2m 4s
# 412:	learn: 0.6270812	total: 5.36s	remaining: 2m 4s
# 413:	learn: 0.6270275	total: 5.37s	remaining: 2m 4s
# 414:	learn: 0.6269637	total: 5.38s	remaining: 2m 4s
# 415:	learn: 0.6269160	total: 5.39s	remaining: 2m 4s
# 416:	learn: 0.6268927	total: 5.4s	remaining: 2m 4s
# 417:	learn: 0.6268870	total: 5.41s	remaining: 2m 4s
# 418:	learn: 0.6268002	total: 5.42s	remaining: 2m 3s
# 419:	learn: 0.6267455	total: 5.43s	remaining: 2m 3s
# 420:	learn: 0.6266269	total: 5.45s	remaining: 2m 4s
# 421:	learn: 0.6265801	total: 5.46s	remaining: 2m 3s
# 422:	learn: 0.6265402	total: 5.47s	remaining: 2m 3s
# 423:	learn: 0.6265177	total: 5.48s	remaining: 2m 3s
# 424:	learn: 0.6264861	total: 5.49s	remaining: 2m 3s
# 425:	learn: 0.6264689	total: 5.5s	remaining: 2m 3s
# 426:	learn: 0.6264143	total: 5.51s	remaining: 2m 3s
# 427:	learn: 0.6263814	total: 5.52s	remaining: 2m 3s
# 428:	learn: 0.6263472	total: 5.54s	remaining: 2m 3s
# 429:	learn: 0.6262984	total: 5.55s	remaining: 2m 3s
# 430:	learn: 0.6262899	total: 5.55s	remaining: 2m 3s
# 431:	learn: 0.6262479	total: 5.57s	remaining: 2m 3s
# 432:	learn: 0.6262389	total: 5.58s	remaining: 2m 3s
# 433:	learn: 0.6261928	total: 5.59s	remaining: 2m 3s
# 434:	learn: 0.6261396	total: 5.6s	remaining: 2m 3s
# 435:	learn: 0.6261112	total: 5.61s	remaining: 2m 3s
# 436:	learn: 0.6260788	total: 5.62s	remaining: 2m 2s
# 437:	learn: 0.6260590	total: 5.63s	remaining: 2m 2s
# 438:	learn: 0.6260509	total: 5.64s	remaining: 2m 2s
# 439:	learn: 0.6260427	total: 5.65s	remaining: 2m 2s
# 440:	learn: 0.6260389	total: 5.66s	remaining: 2m 2s
# 441:	learn: 0.6259825	total: 5.68s	remaining: 2m 2s
# 442:	learn: 0.6259271	total: 5.69s	remaining: 2m 2s
# 443:	learn: 0.6259051	total: 5.7s	remaining: 2m 2s
# 444:	learn: 0.6258689	total: 5.71s	remaining: 2m 2s
# 445:	learn: 0.6258334	total: 5.72s	remaining: 2m 2s
# 446:	learn: 0.6258050	total: 5.73s	remaining: 2m 2s
# 447:	learn: 0.6257626	total: 5.74s	remaining: 2m 2s
# 448:	learn: 0.6256963	total: 5.75s	remaining: 2m 2s
# 449:	learn: 0.6256553	total: 5.76s	remaining: 2m 2s
# 450:	learn: 0.6256428	total: 5.77s	remaining: 2m 2s
# 451:	learn: 0.6256292	total: 5.78s	remaining: 2m 2s
# 452:	learn: 0.6255952	total: 5.79s	remaining: 2m 2s
# 453:	learn: 0.6255756	total: 5.81s	remaining: 2m 2s
# 454:	learn: 0.6255494	total: 5.82s	remaining: 2m 2s
# 455:	learn: 0.6254882	total: 5.83s	remaining: 2m 1s
# 456:	learn: 0.6254839	total: 5.84s	remaining: 2m 1s
# 457:	learn: 0.6253928	total: 5.85s	remaining: 2m 1s
# 458:	learn: 0.6253667	total: 5.86s	remaining: 2m 1s
# 459:	learn: 0.6253533	total: 5.87s	remaining: 2m 1s
# 460:	learn: 0.6253458	total: 5.88s	remaining: 2m 1s
# 461:	learn: 0.6253240	total: 5.9s	remaining: 2m 1s
# 462:	learn: 0.6253066	total: 5.91s	remaining: 2m 1s
# 463:	learn: 0.6252981	total: 5.92s	remaining: 2m 1s
# 464:	learn: 0.6252781	total: 5.93s	remaining: 2m 1s
# 465:	learn: 0.6252319	total: 5.94s	remaining: 2m 1s
# 466:	learn: 0.6252047	total: 5.95s	remaining: 2m 1s
# 467:	learn: 0.6251990	total: 5.96s	remaining: 2m 1s
# 468:	learn: 0.6251865	total: 5.97s	remaining: 2m 1s
# 469:	learn: 0.6251741	total: 5.99s	remaining: 2m 1s
# 470:	learn: 0.6251518	total: 6s	remaining: 2m 1s
# 471:	learn: 0.6251297	total: 6.01s	remaining: 2m 1s
# 472:	learn: 0.6250767	total: 6.02s	remaining: 2m 1s
# 473:	learn: 0.6250596	total: 6.04s	remaining: 2m 1s
# 474:	learn: 0.6250447	total: 6.05s	remaining: 2m 1s
# 475:	learn: 0.6250305	total: 6.1s	remaining: 2m 2s
# 476:	learn: 0.6250123	total: 6.12s	remaining: 2m 2s
# 477:	learn: 0.6249972	total: 6.13s	remaining: 2m 2s
# 478:	learn: 0.6249862	total: 6.14s	remaining: 2m 2s
# 479:	learn: 0.6249623	total: 6.15s	remaining: 2m 2s
# 480:	learn: 0.6249489	total: 6.16s	remaining: 2m 1s
# 481:	learn: 0.6248751	total: 6.18s	remaining: 2m 1s
# 482:	learn: 0.6248318	total: 6.19s	remaining: 2m 1s
# 483:	learn: 0.6247999	total: 6.2s	remaining: 2m 1s
# 484:	learn: 0.6247911	total: 6.21s	remaining: 2m 1s
# 485:	learn: 0.6247510	total: 6.22s	remaining: 2m 1s
# 486:	learn: 0.6247345	total: 6.23s	remaining: 2m 1s
# 487:	learn: 0.6247074	total: 6.24s	remaining: 2m 1s
# 488:	learn: 0.6246871	total: 6.26s	remaining: 2m 1s
# 489:	learn: 0.6246234	total: 6.27s	remaining: 2m 1s
# 490:	learn: 0.6245965	total: 6.29s	remaining: 2m 1s
# 491:	learn: 0.6245791	total: 6.3s	remaining: 2m 1s
# 492:	learn: 0.6245322	total: 6.31s	remaining: 2m 1s
# 493:	learn: 0.6245204	total: 6.32s	remaining: 2m 1s
# 494:	learn: 0.6244967	total: 6.34s	remaining: 2m 1s
# 495:	learn: 0.6244773	total: 6.35s	remaining: 2m 1s
# 496:	learn: 0.6244516	total: 6.36s	remaining: 2m 1s
# 497:	learn: 0.6243919	total: 6.37s	remaining: 2m 1s
# 498:	learn: 0.6243697	total: 6.39s	remaining: 2m 1s
# 499:	learn: 0.6243020	total: 6.4s	remaining: 2m 1s
# 500:	learn: 0.6242816	total: 6.41s	remaining: 2m 1s
# 501:	learn: 0.6242630	total: 6.42s	remaining: 2m 1s
# 502:	learn: 0.6242537	total: 6.43s	remaining: 2m 1s
# 503:	learn: 0.6242157	total: 6.45s	remaining: 2m 1s
# 504:	learn: 0.6242111	total: 6.46s	remaining: 2m 1s
# 505:	learn: 0.6241784	total: 6.47s	remaining: 2m 1s
# 506:	learn: 0.6241684	total: 6.48s	remaining: 2m 1s
# 507:	learn: 0.6241071	total: 6.5s	remaining: 2m 1s
# 508:	learn: 0.6240896	total: 6.51s	remaining: 2m 1s
# 509:	learn: 0.6240732	total: 6.52s	remaining: 2m 1s
# 510:	learn: 0.6240411	total: 6.53s	remaining: 2m 1s
# 511:	learn: 0.6240320	total: 6.54s	remaining: 2m 1s
# 512:	learn: 0.6239907	total: 6.55s	remaining: 2m 1s
# 513:	learn: 0.6239768	total: 6.56s	remaining: 2m 1s
# 514:	learn: 0.6239572	total: 6.57s	remaining: 2m 1s
# 515:	learn: 0.6239466	total: 6.59s	remaining: 2m 1s
# 516:	learn: 0.6239331	total: 6.6s	remaining: 2m 1s
# 517:	learn: 0.6238844	total: 6.61s	remaining: 2m 1s
# 518:	learn: 0.6238712	total: 6.62s	remaining: 2m 1s
# 519:	learn: 0.6238559	total: 6.63s	remaining: 2m
# 520:	learn: 0.6238427	total: 6.65s	remaining: 2m
# 521:	learn: 0.6238364	total: 6.66s	remaining: 2m
# 522:	learn: 0.6238126	total: 6.67s	remaining: 2m
# 523:	learn: 0.6237890	total: 6.69s	remaining: 2m
# 524:	learn: 0.6237745	total: 6.7s	remaining: 2m
# 525:	learn: 0.6237552	total: 6.71s	remaining: 2m
# 526:	learn: 0.6237459	total: 6.72s	remaining: 2m
# 527:	learn: 0.6237046	total: 6.73s	remaining: 2m
# 528:	learn: 0.6236894	total: 6.74s	remaining: 2m
# 529:	learn: 0.6236663	total: 6.75s	remaining: 2m
# 530:	learn: 0.6236624	total: 6.76s	remaining: 2m
# 531:	learn: 0.6236503	total: 6.77s	remaining: 2m
# 532:	learn: 0.6236364	total: 6.78s	remaining: 2m
# 533:	learn: 0.6236139	total: 6.79s	remaining: 2m
# 534:	learn: 0.6235915	total: 6.8s	remaining: 2m
# 535:	learn: 0.6235743	total: 6.81s	remaining: 2m
# 536:	learn: 0.6235433	total: 6.82s	remaining: 2m
# 537:	learn: 0.6235152	total: 6.83s	remaining: 2m
# 538:	learn: 0.6234848	total: 6.85s	remaining: 2m
# 539:	learn: 0.6234697	total: 6.86s	remaining: 2m
# 540:	learn: 0.6234461	total: 6.87s	remaining: 2m
# 541:	learn: 0.6234247	total: 6.88s	remaining: 2m
# 542:	learn: 0.6234070	total: 6.89s	remaining: 2m
# 543:	learn: 0.6233953	total: 6.91s	remaining: 2m
# 544:	learn: 0.6233792	total: 6.92s	remaining: 2m
# 545:	learn: 0.6233757	total: 6.93s	remaining: 1m 59s
# 546:	learn: 0.6233752	total: 6.94s	remaining: 1m 59s
# 547:	learn: 0.6233422	total: 6.95s	remaining: 1m 59s
# 548:	learn: 0.6233335	total: 6.96s	remaining: 1m 59s
# 549:	learn: 0.6233274	total: 6.97s	remaining: 1m 59s
# 550:	learn: 0.6233090	total: 6.98s	remaining: 1m 59s
# 551:	learn: 0.6233007	total: 6.99s	remaining: 1m 59s
# 552:	learn: 0.6232894	total: 7s	remaining: 1m 59s
# 553:	learn: 0.6232689	total: 7.01s	remaining: 1m 59s
# 554:	learn: 0.6232522	total: 7.02s	remaining: 1m 59s
# 555:	learn: 0.6232355	total: 7.03s	remaining: 1m 59s
# 556:	learn: 0.6232230	total: 7.04s	remaining: 1m 59s
# 557:	learn: 0.6232098	total: 7.05s	remaining: 1m 59s
# 558:	learn: 0.6231234	total: 7.07s	remaining: 1m 59s
# 559:	learn: 0.6231194	total: 7.08s	remaining: 1m 59s
# 560:	learn: 0.6230873	total: 7.09s	remaining: 1m 59s
# 561:	learn: 0.6230718	total: 7.1s	remaining: 1m 59s
# 562:	learn: 0.6230620	total: 7.11s	remaining: 1m 59s
# 563:	learn: 0.6230169	total: 7.12s	remaining: 1m 59s
# 564:	learn: 0.6229950	total: 7.13s	remaining: 1m 59s
# 565:	learn: 0.6229687	total: 7.14s	remaining: 1m 59s
# 566:	learn: 0.6229652	total: 7.16s	remaining: 1m 59s
# 567:	learn: 0.6229234	total: 7.17s	remaining: 1m 58s
# 568:	learn: 0.6229210	total: 7.17s	remaining: 1m 58s
# 569:	learn: 0.6229106	total: 7.18s	remaining: 1m 58s
# 570:	learn: 0.6228972	total: 7.2s	remaining: 1m 58s
# 571:	learn: 0.6228898	total: 7.21s	remaining: 1m 58s
# 572:	learn: 0.6228848	total: 7.22s	remaining: 1m 58s
# 573:	learn: 0.6228623	total: 7.23s	remaining: 1m 58s
# 574:	learn: 0.6228489	total: 7.24s	remaining: 1m 58s
# 575:	learn: 0.6228324	total: 7.25s	remaining: 1m 58s
# 576:	learn: 0.6228072	total: 7.26s	remaining: 1m 58s
# 577:	learn: 0.6227622	total: 7.27s	remaining: 1m 58s
# 578:	learn: 0.6227350	total: 7.28s	remaining: 1m 58s
# 579:	learn: 0.6227230	total: 7.29s	remaining: 1m 58s
# 580:	learn: 0.6227021	total: 7.31s	remaining: 1m 58s
# 581:	learn: 0.6226911	total: 7.32s	remaining: 1m 58s
# 582:	learn: 0.6226587	total: 7.33s	remaining: 1m 58s
# 583:	learn: 0.6226507	total: 7.34s	remaining: 1m 58s
# 584:	learn: 0.6226397	total: 7.35s	remaining: 1m 58s
# 585:	learn: 0.6226093	total: 7.36s	remaining: 1m 58s
# 586:	learn: 0.6226042	total: 7.37s	remaining: 1m 58s
# 587:	learn: 0.6225864	total: 7.38s	remaining: 1m 58s
# 588:	learn: 0.6225708	total: 7.39s	remaining: 1m 58s
# 589:	learn: 0.6225564	total: 7.4s	remaining: 1m 58s
# 590:	learn: 0.6225258	total: 7.41s	remaining: 1m 58s
# 591:	learn: 0.6225152	total: 7.42s	remaining: 1m 58s
# 592:	learn: 0.6224955	total: 7.44s	remaining: 1m 57s
# 593:	learn: 0.6224753	total: 7.45s	remaining: 1m 57s
# 594:	learn: 0.6224646	total: 7.46s	remaining: 1m 57s
# 595:	learn: 0.6224545	total: 7.47s	remaining: 1m 57s
# 596:	learn: 0.6224466	total: 7.49s	remaining: 1m 57s
# 597:	learn: 0.6224399	total: 7.5s	remaining: 1m 57s
# 598:	learn: 0.6224327	total: 7.51s	remaining: 1m 57s
# 599:	learn: 0.6224078	total: 7.53s	remaining: 1m 57s
# 600:	learn: 0.6223983	total: 7.54s	remaining: 1m 57s
# 601:	learn: 0.6223844	total: 7.55s	remaining: 1m 57s
# 602:	learn: 0.6223477	total: 7.57s	remaining: 1m 57s
# 603:	learn: 0.6223231	total: 7.58s	remaining: 1m 57s
# 604:	learn: 0.6223092	total: 7.59s	remaining: 1m 57s
# 605:	learn: 0.6222470	total: 7.6s	remaining: 1m 57s
# 606:	learn: 0.6222435	total: 7.61s	remaining: 1m 57s
# 607:	learn: 0.6222248	total: 7.63s	remaining: 1m 57s
# 608:	learn: 0.6221997	total: 7.64s	remaining: 1m 57s
# 609:	learn: 0.6221761	total: 7.65s	remaining: 1m 57s
# 610:	learn: 0.6221518	total: 7.66s	remaining: 1m 57s
# 611:	learn: 0.6221518	total: 7.67s	remaining: 1m 57s
# 612:	learn: 0.6221404	total: 7.68s	remaining: 1m 57s
# 613:	learn: 0.6221385	total: 7.69s	remaining: 1m 57s
# 614:	learn: 0.6221179	total: 7.7s	remaining: 1m 57s
# 615:	learn: 0.6221096	total: 7.71s	remaining: 1m 57s
# 616:	learn: 0.6220991	total: 7.72s	remaining: 1m 57s
# 617:	learn: 0.6220896	total: 7.74s	remaining: 1m 57s
# 618:	learn: 0.6220896	total: 7.74s	remaining: 1m 57s
# 619:	learn: 0.6220747	total: 7.75s	remaining: 1m 57s
# 620:	learn: 0.6220676	total: 7.76s	remaining: 1m 57s
# 621:	learn: 0.6220398	total: 7.78s	remaining: 1m 57s
# 622:	learn: 0.6220367	total: 7.78s	remaining: 1m 57s
# 623:	learn: 0.6220258	total: 7.79s	remaining: 1m 57s
# 624:	learn: 0.6220187	total: 7.8s	remaining: 1m 57s
# 625:	learn: 0.6220042	total: 7.82s	remaining: 1m 57s
# 626:	learn: 0.6219960	total: 7.83s	remaining: 1m 56s
# 627:	learn: 0.6219960	total: 7.83s	remaining: 1m 56s
# 628:	learn: 0.6219810	total: 7.84s	remaining: 1m 56s
# 629:	learn: 0.6219789	total: 7.85s	remaining: 1m 56s
# 630:	learn: 0.6219361	total: 7.86s	remaining: 1m 56s
# 631:	learn: 0.6219271	total: 7.87s	remaining: 1m 56s
# 632:	learn: 0.6219009	total: 7.88s	remaining: 1m 56s
# 633:	learn: 0.6218972	total: 7.89s	remaining: 1m 56s
# 634:	learn: 0.6218671	total: 7.91s	remaining: 1m 56s
# 635:	learn: 0.6218631	total: 7.92s	remaining: 1m 56s
# 636:	learn: 0.6218466	total: 7.93s	remaining: 1m 56s
# 637:	learn: 0.6218405	total: 7.94s	remaining: 1m 56s
# 638:	learn: 0.6218134	total: 7.95s	remaining: 1m 56s
# 639:	learn: 0.6217922	total: 7.96s	remaining: 1m 56s
# 640:	learn: 0.6217727	total: 7.98s	remaining: 1m 56s
# 641:	learn: 0.6217699	total: 7.99s	remaining: 1m 56s
# 642:	learn: 0.6217654	total: 8s	remaining: 1m 56s
# 643:	learn: 0.6217591	total: 8.01s	remaining: 1m 56s
# 644:	learn: 0.6217536	total: 8.02s	remaining: 1m 56s
# 645:	learn: 0.6217484	total: 8.03s	remaining: 1m 56s
# 646:	learn: 0.6217375	total: 8.04s	remaining: 1m 56s
# 647:	learn: 0.6217344	total: 8.05s	remaining: 1m 56s
# 648:	learn: 0.6217265	total: 8.06s	remaining: 1m 56s
# 649:	learn: 0.6216826	total: 8.07s	remaining: 1m 56s
# 650:	learn: 0.6216734	total: 8.08s	remaining: 1m 56s
# 651:	learn: 0.6216634	total: 8.1s	remaining: 1m 56s
# 652:	learn: 0.6216573	total: 8.11s	remaining: 1m 56s
# 653:	learn: 0.6216491	total: 8.12s	remaining: 1m 56s
# 654:	learn: 0.6216478	total: 8.13s	remaining: 1m 56s
# 655:	learn: 0.6216266	total: 8.14s	remaining: 1m 56s
# 656:	learn: 0.6216165	total: 8.16s	remaining: 1m 56s
# 657:	learn: 0.6215511	total: 8.17s	remaining: 1m 56s
# 658:	learn: 0.6215328	total: 8.19s	remaining: 1m 56s
# 659:	learn: 0.6215261	total: 8.2s	remaining: 1m 56s
# 660:	learn: 0.6215114	total: 8.21s	remaining: 1m 56s
# 661:	learn: 0.6214937	total: 8.23s	remaining: 1m 56s
# 662:	learn: 0.6214937	total: 8.23s	remaining: 1m 55s
# 663:	learn: 0.6214702	total: 8.25s	remaining: 1m 55s
# 664:	learn: 0.6214613	total: 8.26s	remaining: 1m 55s
# 665:	learn: 0.6214070	total: 8.27s	remaining: 1m 55s
# 666:	learn: 0.6214021	total: 8.28s	remaining: 1m 55s
# 667:	learn: 0.6213783	total: 8.3s	remaining: 1m 55s
# 668:	learn: 0.6213753	total: 8.31s	remaining: 1m 55s
# 669:	learn: 0.6213550	total: 8.32s	remaining: 1m 55s
# 670:	learn: 0.6213518	total: 8.33s	remaining: 1m 55s
# 671:	learn: 0.6213518	total: 8.34s	remaining: 1m 55s
# 672:	learn: 0.6213084	total: 8.35s	remaining: 1m 55s
# 673:	learn: 0.6212761	total: 8.36s	remaining: 1m 55s
# 674:	learn: 0.6212671	total: 8.38s	remaining: 1m 55s
# 675:	learn: 0.6212562	total: 8.39s	remaining: 1m 55s
# 676:	learn: 0.6212502	total: 8.4s	remaining: 1m 55s
# 677:	learn: 0.6212481	total: 8.41s	remaining: 1m 55s
# 678:	learn: 0.6212420	total: 8.42s	remaining: 1m 55s
# 679:	learn: 0.6212164	total: 8.44s	remaining: 1m 55s
# 680:	learn: 0.6212033	total: 8.45s	remaining: 1m 55s
# 681:	learn: 0.6211966	total: 8.46s	remaining: 1m 55s
# 682:	learn: 0.6211846	total: 8.47s	remaining: 1m 55s
# 683:	learn: 0.6211744	total: 8.48s	remaining: 1m 55s
# 684:	learn: 0.6211554	total: 8.5s	remaining: 1m 55s
# 685:	learn: 0.6211524	total: 8.51s	remaining: 1m 55s
# 686:	learn: 0.6211422	total: 8.52s	remaining: 1m 55s
# 687:	learn: 0.6211104	total: 8.54s	remaining: 1m 55s
# 688:	learn: 0.6211067	total: 8.55s	remaining: 1m 55s
# 689:	learn: 0.6210904	total: 8.56s	remaining: 1m 55s
# 690:	learn: 0.6210850	total: 8.58s	remaining: 1m 55s
# 691:	learn: 0.6210778	total: 8.6s	remaining: 1m 55s
# 692:	learn: 0.6210742	total: 8.61s	remaining: 1m 55s
# 693:	learn: 0.6210701	total: 8.62s	remaining: 1m 55s
# 694:	learn: 0.6210627	total: 8.64s	remaining: 1m 55s
# 695:	learn: 0.6210348	total: 8.65s	remaining: 1m 55s
# 696:	learn: 0.6210245	total: 8.66s	remaining: 1m 55s
# 697:	learn: 0.6209925	total: 8.68s	remaining: 1m 55s
# 698:	learn: 0.6209803	total: 8.7s	remaining: 1m 55s
# 699:	learn: 0.6209788	total: 8.71s	remaining: 1m 55s
# 700:	learn: 0.6209758	total: 8.73s	remaining: 1m 55s
# 701:	learn: 0.6209758	total: 8.74s	remaining: 1m 55s
# 702:	learn: 0.6209573	total: 8.76s	remaining: 1m 55s
# 703:	learn: 0.6209478	total: 8.77s	remaining: 1m 55s
# 704:	learn: 0.6209383	total: 8.79s	remaining: 1m 55s
# 705:	learn: 0.6209360	total: 8.8s	remaining: 1m 55s
# 706:	learn: 0.6209293	total: 8.83s	remaining: 1m 56s
# 707:	learn: 0.6209181	total: 8.84s	remaining: 1m 56s
# 708:	learn: 0.6209011	total: 8.86s	remaining: 1m 56s
# 709:	learn: 0.6208892	total: 8.88s	remaining: 1m 56s
# 710:	learn: 0.6208699	total: 8.89s	remaining: 1m 56s
# 711:	learn: 0.6208561	total: 8.91s	remaining: 1m 56s
# 712:	learn: 0.6208364	total: 8.93s	remaining: 1m 56s
# 713:	learn: 0.6208145	total: 8.94s	remaining: 1m 56s
# 714:	learn: 0.6208113	total: 8.96s	remaining: 1m 56s
# 715:	learn: 0.6208015	total: 8.98s	remaining: 1m 56s
# 716:	learn: 0.6207934	total: 8.99s	remaining: 1m 56s
# 717:	learn: 0.6207816	total: 9.01s	remaining: 1m 56s
# 718:	learn: 0.6207787	total: 9.03s	remaining: 1m 56s
# 719:	learn: 0.6207725	total: 9.04s	remaining: 1m 56s
# 720:	learn: 0.6207653	total: 9.06s	remaining: 1m 56s
# 721:	learn: 0.6207576	total: 9.07s	remaining: 1m 56s
# 722:	learn: 0.6207545	total: 9.08s	remaining: 1m 56s
# 723:	learn: 0.6207524	total: 9.1s	remaining: 1m 56s
# 724:	learn: 0.6207270	total: 9.11s	remaining: 1m 56s
# 725:	learn: 0.6207174	total: 9.12s	remaining: 1m 56s
# 726:	learn: 0.6206981	total: 9.13s	remaining: 1m 56s
# 727:	learn: 0.6206952	total: 9.14s	remaining: 1m 56s
# 728:	learn: 0.6206875	total: 9.15s	remaining: 1m 56s
# 729:	learn: 0.6206769	total: 9.16s	remaining: 1m 56s
# 730:	learn: 0.6206395	total: 9.17s	remaining: 1m 56s
# 731:	learn: 0.6206331	total: 9.18s	remaining: 1m 56s
# 732:	learn: 0.6206200	total: 9.2s	remaining: 1m 56s
# 733:	learn: 0.6205770	total: 9.21s	remaining: 1m 56s
# 734:	learn: 0.6205625	total: 9.22s	remaining: 1m 56s
# 735:	learn: 0.6205527	total: 9.23s	remaining: 1m 56s
# 736:	learn: 0.6205404	total: 9.25s	remaining: 1m 56s
# 737:	learn: 0.6205076	total: 9.26s	remaining: 1m 56s
# 738:	learn: 0.6205037	total: 9.27s	remaining: 1m 56s
# 739:	learn: 0.6204866	total: 9.28s	remaining: 1m 56s
# 740:	learn: 0.6204778	total: 9.29s	remaining: 1m 56s
# 741:	learn: 0.6204689	total: 9.3s	remaining: 1m 56s
# 742:	learn: 0.6204644	total: 9.31s	remaining: 1m 55s
# 743:	learn: 0.6204510	total: 9.32s	remaining: 1m 55s
# 744:	learn: 0.6204378	total: 9.33s	remaining: 1m 55s
# 745:	learn: 0.6204299	total: 9.34s	remaining: 1m 55s
# 746:	learn: 0.6204163	total: 9.35s	remaining: 1m 55s
# 747:	learn: 0.6204100	total: 9.36s	remaining: 1m 55s
# 748:	learn: 0.6204042	total: 9.37s	remaining: 1m 55s
# 749:	learn: 0.6203987	total: 9.38s	remaining: 1m 55s
# 750:	learn: 0.6203873	total: 9.39s	remaining: 1m 55s
# 751:	learn: 0.6203414	total: 9.4s	remaining: 1m 55s
# 752:	learn: 0.6203374	total: 9.42s	remaining: 1m 55s
# 753:	learn: 0.6203274	total: 9.43s	remaining: 1m 55s
# 754:	learn: 0.6203147	total: 9.44s	remaining: 1m 55s
# 755:	learn: 0.6202897	total: 9.45s	remaining: 1m 55s
# 756:	learn: 0.6202871	total: 9.46s	remaining: 1m 55s
# 757:	learn: 0.6202836	total: 9.47s	remaining: 1m 55s
# 758:	learn: 0.6202768	total: 9.49s	remaining: 1m 55s
# 759:	learn: 0.6202724	total: 9.5s	remaining: 1m 55s
# 760:	learn: 0.6202679	total: 9.51s	remaining: 1m 55s
# 761:	learn: 0.6202506	total: 9.52s	remaining: 1m 55s
# 762:	learn: 0.6202401	total: 9.53s	remaining: 1m 55s
# 763:	learn: 0.6202322	total: 9.54s	remaining: 1m 55s
# 764:	learn: 0.6202282	total: 9.55s	remaining: 1m 55s
# 765:	learn: 0.6202177	total: 9.56s	remaining: 1m 55s
# 766:	learn: 0.6202081	total: 9.57s	remaining: 1m 55s
# 767:	learn: 0.6201959	total: 9.58s	remaining: 1m 55s
# 768:	learn: 0.6201827	total: 9.59s	remaining: 1m 55s
# 769:	learn: 0.6201510	total: 9.6s	remaining: 1m 55s
# 770:	learn: 0.6201371	total: 9.62s	remaining: 1m 55s
# 771:	learn: 0.6201350	total: 9.63s	remaining: 1m 55s
# 772:	learn: 0.6201243	total: 9.64s	remaining: 1m 55s
# 773:	learn: 0.6201198	total: 9.65s	remaining: 1m 55s
# 774:	learn: 0.6201029	total: 9.66s	remaining: 1m 54s
# 775:	learn: 0.6200946	total: 9.67s	remaining: 1m 54s
# 776:	learn: 0.6200893	total: 9.68s	remaining: 1m 54s
# 777:	learn: 0.6200812	total: 9.69s	remaining: 1m 54s
# 778:	learn: 0.6200711	total: 9.7s	remaining: 1m 54s
# 779:	learn: 0.6200701	total: 9.71s	remaining: 1m 54s
# 780:	learn: 0.6200596	total: 9.72s	remaining: 1m 54s
# 781:	learn: 0.6200486	total: 9.73s	remaining: 1m 54s
# 782:	learn: 0.6200398	total: 9.74s	remaining: 1m 54s
# 783:	learn: 0.6200398	total: 9.75s	remaining: 1m 54s
# 784:	learn: 0.6200114	total: 9.76s	remaining: 1m 54s
# 785:	learn: 0.6199942	total: 9.77s	remaining: 1m 54s
# 786:	learn: 0.6199902	total: 9.78s	remaining: 1m 54s
# 787:	learn: 0.6199727	total: 9.79s	remaining: 1m 54s
# 788:	learn: 0.6199580	total: 9.8s	remaining: 1m 54s
# 789:	learn: 0.6199548	total: 9.82s	remaining: 1m 54s
# 790:	learn: 0.6199415	total: 9.83s	remaining: 1m 54s
# 791:	learn: 0.6199366	total: 9.84s	remaining: 1m 54s
# 792:	learn: 0.6199342	total: 9.85s	remaining: 1m 54s
# 793:	learn: 0.6199208	total: 9.86s	remaining: 1m 54s
# 794:	learn: 0.6199123	total: 9.87s	remaining: 1m 54s
# 795:	learn: 0.6199071	total: 9.88s	remaining: 1m 54s
# 796:	learn: 0.6199007	total: 9.89s	remaining: 1m 54s
# 797:	learn: 0.6198976	total: 9.9s	remaining: 1m 54s
# 798:	learn: 0.6198930	total: 9.91s	remaining: 1m 54s
# 799:	learn: 0.6198888	total: 9.92s	remaining: 1m 54s
# 800:	learn: 0.6198875	total: 9.94s	remaining: 1m 54s
# 801:	learn: 0.6198817	total: 9.95s	remaining: 1m 54s
# 802:	learn: 0.6198735	total: 9.96s	remaining: 1m 54s
# 803:	learn: 0.6198724	total: 9.97s	remaining: 1m 54s
# 804:	learn: 0.6198647	total: 9.98s	remaining: 1m 53s
# 805:	learn: 0.6198540	total: 9.99s	remaining: 1m 53s
# 806:	learn: 0.6198157	total: 10s	remaining: 1m 53s
# 807:	learn: 0.6198037	total: 10s	remaining: 1m 53s
# 808:	learn: 0.6197987	total: 10s	remaining: 1m 53s
# 809:	learn: 0.6197952	total: 10s	remaining: 1m 53s
# 810:	learn: 0.6197870	total: 10.1s	remaining: 1m 53s
# 811:	learn: 0.6197687	total: 10.1s	remaining: 1m 53s
# 812:	learn: 0.6197599	total: 10.1s	remaining: 1m 53s
# 813:	learn: 0.6197570	total: 10.1s	remaining: 1m 53s
# 814:	learn: 0.6197545	total: 10.1s	remaining: 1m 53s
# 815:	learn: 0.6197445	total: 10.1s	remaining: 1m 53s
# 816:	learn: 0.6197434	total: 10.1s	remaining: 1m 53s
# 817:	learn: 0.6197366	total: 10.1s	remaining: 1m 53s
# 818:	learn: 0.6197348	total: 10.1s	remaining: 1m 53s
# 819:	learn: 0.6197320	total: 10.1s	remaining: 1m 53s
# 820:	learn: 0.6197252	total: 10.2s	remaining: 1m 53s
# 821:	learn: 0.6197206	total: 10.2s	remaining: 1m 53s
# 822:	learn: 0.6197172	total: 10.2s	remaining: 1m 53s
# 823:	learn: 0.6197085	total: 10.2s	remaining: 1m 53s
# 824:	learn: 0.6197065	total: 10.2s	remaining: 1m 53s
# 825:	learn: 0.6196884	total: 10.2s	remaining: 1m 53s
# 826:	learn: 0.6196618	total: 10.2s	remaining: 1m 53s
# 827:	learn: 0.6196618	total: 10.2s	remaining: 1m 53s
# 828:	learn: 0.6196534	total: 10.2s	remaining: 1m 53s
# 829:	learn: 0.6196518	total: 10.2s	remaining: 1m 53s
# 830:	learn: 0.6196472	total: 10.3s	remaining: 1m 53s
# 831:	learn: 0.6196392	total: 10.3s	remaining: 1m 53s
# 832:	learn: 0.6196308	total: 10.3s	remaining: 1m 53s
# 833:	learn: 0.6196259	total: 10.3s	remaining: 1m 53s
# 834:	learn: 0.6196142	total: 10.3s	remaining: 1m 53s
# 835:	learn: 0.6195982	total: 10.3s	remaining: 1m 53s
# 836:	learn: 0.6195910	total: 10.3s	remaining: 1m 53s
# 837:	learn: 0.6195859	total: 10.3s	remaining: 1m 52s
# 838:	learn: 0.6195819	total: 10.3s	remaining: 1m 52s
# 839:	learn: 0.6195699	total: 10.4s	remaining: 1m 52s
# 840:	learn: 0.6195636	total: 10.4s	remaining: 1m 52s
# 841:	learn: 0.6195589	total: 10.4s	remaining: 1m 52s
# 842:	learn: 0.6195534	total: 10.4s	remaining: 1m 52s
# 843:	learn: 0.6195510	total: 10.4s	remaining: 1m 52s
# 844:	learn: 0.6195295	total: 10.4s	remaining: 1m 52s
# 845:	learn: 0.6195195	total: 10.4s	remaining: 1m 52s
# 846:	learn: 0.6195187	total: 10.4s	remaining: 1m 52s
# 847:	learn: 0.6195083	total: 10.4s	remaining: 1m 52s
# 848:	learn: 0.6195048	total: 10.5s	remaining: 1m 52s
# 849:	learn: 0.6194980	total: 10.5s	remaining: 1m 52s
# 850:	learn: 0.6194927	total: 10.5s	remaining: 1m 52s
# 851:	learn: 0.6194856	total: 10.5s	remaining: 1m 52s
# 852:	learn: 0.6194812	total: 10.5s	remaining: 1m 52s
# 853:	learn: 0.6194794	total: 10.5s	remaining: 1m 52s
# 854:	learn: 0.6194737	total: 10.5s	remaining: 1m 52s
# 855:	learn: 0.6194639	total: 10.5s	remaining: 1m 52s
# 856:	learn: 0.6194455	total: 10.5s	remaining: 1m 52s
# 857:	learn: 0.6194397	total: 10.6s	remaining: 1m 52s
# 858:	learn: 0.6194325	total: 10.6s	remaining: 1m 52s
# 859:	learn: 0.6194323	total: 10.6s	remaining: 1m 52s
# 860:	learn: 0.6194123	total: 10.6s	remaining: 1m 52s
# 861:	learn: 0.6194101	total: 10.6s	remaining: 1m 52s
# 862:	learn: 0.6194086	total: 10.6s	remaining: 1m 52s
# 863:	learn: 0.6193929	total: 10.6s	remaining: 1m 52s
# 864:	learn: 0.6193710	total: 10.6s	remaining: 1m 52s
# 865:	learn: 0.6193670	total: 10.6s	remaining: 1m 52s
# 866:	learn: 0.6193653	total: 10.7s	remaining: 1m 52s
# 867:	learn: 0.6193561	total: 10.7s	remaining: 1m 52s
# 868:	learn: 0.6193401	total: 10.7s	remaining: 1m 52s
# 869:	learn: 0.6193373	total: 10.7s	remaining: 1m 52s
# 870:	learn: 0.6193337	total: 10.7s	remaining: 1m 52s
# 871:	learn: 0.6193201	total: 10.7s	remaining: 1m 52s
# 872:	learn: 0.6193155	total: 10.8s	remaining: 1m 52s
# 873:	learn: 0.6193139	total: 10.8s	remaining: 1m 52s
# 874:	learn: 0.6193073	total: 10.8s	remaining: 1m 52s
# 875:	learn: 0.6193051	total: 10.8s	remaining: 1m 52s
# 876:	learn: 0.6192992	total: 10.8s	remaining: 1m 52s
# 877:	learn: 0.6192878	total: 10.8s	remaining: 1m 52s
# 878:	learn: 0.6192768	total: 10.8s	remaining: 1m 52s
# 879:	learn: 0.6192635	total: 10.8s	remaining: 1m 52s
# 880:	learn: 0.6192470	total: 10.8s	remaining: 1m 52s
# 881:	learn: 0.6192465	total: 10.8s	remaining: 1m 52s
# 882:	learn: 0.6192430	total: 10.9s	remaining: 1m 52s
# 883:	learn: 0.6192232	total: 10.9s	remaining: 1m 52s
# 884:	learn: 0.6192168	total: 10.9s	remaining: 1m 52s
# 885:	learn: 0.6192121	total: 10.9s	remaining: 1m 52s
# 886:	learn: 0.6192054	total: 10.9s	remaining: 1m 52s
# 887:	learn: 0.6191956	total: 10.9s	remaining: 1m 52s
# 888:	learn: 0.6191794	total: 10.9s	remaining: 1m 52s
# 889:	learn: 0.6191766	total: 10.9s	remaining: 1m 51s
# 890:	learn: 0.6191707	total: 11s	remaining: 1m 51s
# 891:	learn: 0.6191593	total: 11s	remaining: 1m 51s
# 892:	learn: 0.6191578	total: 11s	remaining: 1m 51s
# 893:	learn: 0.6191549	total: 11s	remaining: 1m 51s
# 894:	learn: 0.6191502	total: 11s	remaining: 1m 51s
# 895:	learn: 0.6191454	total: 11s	remaining: 1m 51s
# 896:	learn: 0.6191436	total: 11s	remaining: 1m 51s
# 897:	learn: 0.6191339	total: 11s	remaining: 1m 51s
# 898:	learn: 0.6191304	total: 11s	remaining: 1m 51s
# 899:	learn: 0.6191179	total: 11s	remaining: 1m 51s
# 900:	learn: 0.6191098	total: 11.1s	remaining: 1m 51s
# 901:	learn: 0.6191040	total: 11.1s	remaining: 1m 51s
# 902:	learn: 0.6191000	total: 11.1s	remaining: 1m 51s
# 903:	learn: 0.6190993	total: 11.1s	remaining: 1m 51s
# 904:	learn: 0.6190965	total: 11.1s	remaining: 1m 51s
# 905:	learn: 0.6190862	total: 11.1s	remaining: 1m 51s
# 906:	learn: 0.6190779	total: 11.1s	remaining: 1m 51s
# 907:	learn: 0.6190760	total: 11.1s	remaining: 1m 51s
# 908:	learn: 0.6190742	total: 11.1s	remaining: 1m 51s
# 909:	learn: 0.6190724	total: 11.2s	remaining: 1m 51s
# 910:	learn: 0.6190704	total: 11.2s	remaining: 1m 51s
# 911:	learn: 0.6190653	total: 11.2s	remaining: 1m 51s
# 912:	learn: 0.6190630	total: 11.2s	remaining: 1m 51s
# 913:	learn: 0.6190512	total: 11.2s	remaining: 1m 51s
# 914:	learn: 0.6190468	total: 11.2s	remaining: 1m 51s
# 915:	learn: 0.6190444	total: 11.2s	remaining: 1m 51s
# 916:	learn: 0.6190430	total: 11.2s	remaining: 1m 51s
# 917:	learn: 0.6190361	total: 11.2s	remaining: 1m 51s
# 918:	learn: 0.6190263	total: 11.3s	remaining: 1m 51s
# ...
# 9710:	learn: 0.6143587	total: 1m 44s	remaining: 3.1s
# 9711:	learn: 0.6143587	total: 1m 44s	remaining: 3.09s
# 9712:	learn: 0.6143587	total: 1m 44s	remaining: 3.08s
# 9713:	learn: 0.6143586	total: 1m 44s	remaining: 3.07s
# 9714:	learn: 0.6143586	total: 1m 44s	remaining: 3.06s
# 9715:	learn: 0.6143586	total: 1m 44s	remaining: 3.05s
# 9716:	learn: 0.6143586	total: 1m 44s	remaining: 3.04s
# 9717:	learn: 0.6143585	total: 1m 44s	remaining: 3.03s
# 9718:	learn: 0.6143585	total: 1m 44s	remaining: 3.02s
# 9719:	learn: 0.6143585	total: 1m 44s	remaining: 3.01s
# 9720:	learn: 0.6143583	total: 1m 44s	remaining: 3s
# 9721:	learn: 0.6143583	total: 1m 44s	remaining: 2.98s
# 9722:	learn: 0.6143582	total: 1m 44s	remaining: 2.98s
# 9723:	learn: 0.6143582	total: 1m 44s	remaining: 2.96s
# 9724:	learn: 0.6143582	total: 1m 44s	remaining: 2.95s
# 9725:	learn: 0.6143582	total: 1m 44s	remaining: 2.94s
# 9726:	learn: 0.6143581	total: 1m 44s	remaining: 2.93s
# 9727:	learn: 0.6143581	total: 1m 44s	remaining: 2.92s
# 9728:	learn: 0.6143581	total: 1m 44s	remaining: 2.91s
# 9729:	learn: 0.6143581	total: 1m 44s	remaining: 2.9s
# 9730:	learn: 0.6143580	total: 1m 44s	remaining: 2.89s
# 9731:	learn: 0.6143580	total: 1m 44s	remaining: 2.88s
# 9732:	learn: 0.6143580	total: 1m 44s	remaining: 2.87s
# 9733:	learn: 0.6143580	total: 1m 44s	remaining: 2.86s
# 9734:	learn: 0.6143580	total: 1m 44s	remaining: 2.85s
# 9735:	learn: 0.6143580	total: 1m 44s	remaining: 2.83s
# 9736:	learn: 0.6143580	total: 1m 44s	remaining: 2.82s
# 9737:	learn: 0.6143578	total: 1m 44s	remaining: 2.81s
# 9738:	learn: 0.6143578	total: 1m 44s	remaining: 2.8s
# 9739:	learn: 0.6143578	total: 1m 44s	remaining: 2.79s
# 9740:	learn: 0.6143578	total: 1m 44s	remaining: 2.78s
# 9741:	learn: 0.6143578	total: 1m 44s	remaining: 2.77s
# 9742:	learn: 0.6143578	total: 1m 44s	remaining: 2.76s
# 9743:	learn: 0.6143578	total: 1m 44s	remaining: 2.75s
# 9744:	learn: 0.6143577	total: 1m 44s	remaining: 2.74s
# 9745:	learn: 0.6143577	total: 1m 44s	remaining: 2.73s
# 9746:	learn: 0.6143577	total: 1m 44s	remaining: 2.72s
# 9747:	learn: 0.6143576	total: 1m 44s	remaining: 2.71s
# 9748:	learn: 0.6143576	total: 1m 44s	remaining: 2.69s
# 9749:	learn: 0.6143576	total: 1m 44s	remaining: 2.68s
# 9750:	learn: 0.6143576	total: 1m 44s	remaining: 2.67s
# 9751:	learn: 0.6143576	total: 1m 44s	remaining: 2.66s
# 9752:	learn: 0.6143576	total: 1m 44s	remaining: 2.65s
# 9753:	learn: 0.6143576	total: 1m 44s	remaining: 2.64s
# 9754:	learn: 0.6143576	total: 1m 44s	remaining: 2.63s
# 9755:	learn: 0.6143576	total: 1m 44s	remaining: 2.62s
# 9756:	learn: 0.6143576	total: 1m 44s	remaining: 2.61s
# 9757:	learn: 0.6143576	total: 1m 44s	remaining: 2.6s
# 9758:	learn: 0.6143576	total: 1m 44s	remaining: 2.59s
# 9759:	learn: 0.6143576	total: 1m 44s	remaining: 2.58s
# 9760:	learn: 0.6143576	total: 1m 44s	remaining: 2.57s
# 9761:	learn: 0.6143569	total: 1m 44s	remaining: 2.56s
# 9762:	learn: 0.6143569	total: 1m 44s	remaining: 2.54s
# 9763:	learn: 0.6143569	total: 1m 44s	remaining: 2.53s
# 9764:	learn: 0.6143569	total: 1m 44s	remaining: 2.52s
# 9765:	learn: 0.6143569	total: 1m 44s	remaining: 2.51s
# 9766:	learn: 0.6143567	total: 1m 44s	remaining: 2.5s
# 9767:	learn: 0.6143567	total: 1m 44s	remaining: 2.49s
# 9768:	learn: 0.6143567	total: 1m 44s	remaining: 2.48s
# 9769:	learn: 0.6143567	total: 1m 44s	remaining: 2.47s
# 9770:	learn: 0.6143567	total: 1m 44s	remaining: 2.46s
# 9771:	learn: 0.6143567	total: 1m 44s	remaining: 2.45s
# 9772:	learn: 0.6143567	total: 1m 44s	remaining: 2.44s
# 9773:	learn: 0.6143566	total: 1m 44s	remaining: 2.43s
# 9774:	learn: 0.6143566	total: 1m 44s	remaining: 2.42s
# 9775:	learn: 0.6143566	total: 1m 44s	remaining: 2.4s
# 9776:	learn: 0.6143566	total: 1m 44s	remaining: 2.39s
# 9777:	learn: 0.6143566	total: 1m 44s	remaining: 2.38s
# 9778:	learn: 0.6143566	total: 1m 44s	remaining: 2.37s
# 9779:	learn: 0.6143566	total: 1m 45s	remaining: 2.36s
# 9780:	learn: 0.6143566	total: 1m 45s	remaining: 2.35s
# 9781:	learn: 0.6143565	total: 1m 45s	remaining: 2.34s
# 9782:	learn: 0.6143564	total: 1m 45s	remaining: 2.33s
# 9783:	learn: 0.6143564	total: 1m 45s	remaining: 2.32s
# 9784:	learn: 0.6143564	total: 1m 45s	remaining: 2.31s
# 9785:	learn: 0.6143564	total: 1m 45s	remaining: 2.3s
# 9786:	learn: 0.6143564	total: 1m 45s	remaining: 2.29s
# 9787:	learn: 0.6143564	total: 1m 45s	remaining: 2.28s
# 9788:	learn: 0.6143564	total: 1m 45s	remaining: 2.27s
# 9789:	learn: 0.6143564	total: 1m 45s	remaining: 2.25s
# 9790:	learn: 0.6143564	total: 1m 45s	remaining: 2.24s
# 9791:	learn: 0.6143564	total: 1m 45s	remaining: 2.23s
# 9792:	learn: 0.6143564	total: 1m 45s	remaining: 2.22s
# 9793:	learn: 0.6143563	total: 1m 45s	remaining: 2.21s
# 9794:	learn: 0.6143562	total: 1m 45s	remaining: 2.2s
# 9795:	learn: 0.6143562	total: 1m 45s	remaining: 2.19s
# 9796:	learn: 0.6143562	total: 1m 45s	remaining: 2.18s
# 9797:	learn: 0.6143562	total: 1m 45s	remaining: 2.17s
# 9798:	learn: 0.6143562	total: 1m 45s	remaining: 2.16s
# 9799:	learn: 0.6143560	total: 1m 45s	remaining: 2.15s
# 9800:	learn: 0.6143560	total: 1m 45s	remaining: 2.14s
# 9801:	learn: 0.6143560	total: 1m 45s	remaining: 2.13s
# 9802:	learn: 0.6143560	total: 1m 45s	remaining: 2.12s
# 9803:	learn: 0.6143560	total: 1m 45s	remaining: 2.1s
# 9804:	learn: 0.6143559	total: 1m 45s	remaining: 2.09s
# 9805:	learn: 0.6143558	total: 1m 45s	remaining: 2.08s
# 9806:	learn: 0.6143558	total: 1m 45s	remaining: 2.07s
# 9807:	learn: 0.6143558	total: 1m 45s	remaining: 2.06s
# 9808:	learn: 0.6143557	total: 1m 45s	remaining: 2.05s
# 9809:	learn: 0.6143557	total: 1m 45s	remaining: 2.04s
# 9810:	learn: 0.6143557	total: 1m 45s	remaining: 2.03s
# 9811:	learn: 0.6143557	total: 1m 45s	remaining: 2.02s
# 9812:	learn: 0.6143557	total: 1m 45s	remaining: 2.01s
# 9813:	learn: 0.6143557	total: 1m 45s	remaining: 2s
# 9814:	learn: 0.6143557	total: 1m 45s	remaining: 1.99s
# 9815:	learn: 0.6143557	total: 1m 45s	remaining: 1.98s
# 9816:	learn: 0.6143557	total: 1m 45s	remaining: 1.96s
# 9817:	learn: 0.6143557	total: 1m 45s	remaining: 1.95s
# 9818:	learn: 0.6143557	total: 1m 45s	remaining: 1.94s
# 9819:	learn: 0.6143555	total: 1m 45s	remaining: 1.93s
# 9820:	learn: 0.6143555	total: 1m 45s	remaining: 1.92s
# 9821:	learn: 0.6143555	total: 1m 45s	remaining: 1.91s
# 9822:	learn: 0.6143555	total: 1m 45s	remaining: 1.9s
# 9823:	learn: 0.6143555	total: 1m 45s	remaining: 1.89s
# 9824:	learn: 0.6143555	total: 1m 45s	remaining: 1.88s
# 9825:	learn: 0.6143555	total: 1m 45s	remaining: 1.87s
# 9826:	learn: 0.6143555	total: 1m 45s	remaining: 1.86s
# 9827:	learn: 0.6143555	total: 1m 45s	remaining: 1.85s
# 9828:	learn: 0.6143555	total: 1m 45s	remaining: 1.83s
# 9829:	learn: 0.6143555	total: 1m 45s	remaining: 1.82s
# 9830:	learn: 0.6143555	total: 1m 45s	remaining: 1.81s
# 9831:	learn: 0.6143554	total: 1m 45s	remaining: 1.8s
# 9832:	learn: 0.6143554	total: 1m 45s	remaining: 1.79s
# 9833:	learn: 0.6143554	total: 1m 45s	remaining: 1.78s
# 9834:	learn: 0.6143554	total: 1m 45s	remaining: 1.77s
# 9835:	learn: 0.6143554	total: 1m 45s	remaining: 1.76s
# 9836:	learn: 0.6143554	total: 1m 45s	remaining: 1.75s
# 9837:	learn: 0.6143554	total: 1m 45s	remaining: 1.74s
# 9838:	learn: 0.6143554	total: 1m 45s	remaining: 1.73s
# 9839:	learn: 0.6143554	total: 1m 45s	remaining: 1.72s
# 9840:	learn: 0.6143554	total: 1m 45s	remaining: 1.71s
# 9841:	learn: 0.6143554	total: 1m 45s	remaining: 1.7s
# 9842:	learn: 0.6143554	total: 1m 45s	remaining: 1.69s
# 9843:	learn: 0.6143554	total: 1m 45s	remaining: 1.67s
# 9844:	learn: 0.6143553	total: 1m 45s	remaining: 1.66s
# 9845:	learn: 0.6143553	total: 1m 45s	remaining: 1.65s
# 9846:	learn: 0.6143553	total: 1m 45s	remaining: 1.64s
# 9847:	learn: 0.6143553	total: 1m 45s	remaining: 1.63s
# 9848:	learn: 0.6143553	total: 1m 45s	remaining: 1.62s
# 9849:	learn: 0.6143553	total: 1m 45s	remaining: 1.61s
# 9850:	learn: 0.6143552	total: 1m 45s	remaining: 1.6s
# 9851:	learn: 0.6143551	total: 1m 45s	remaining: 1.59s
# 9852:	learn: 0.6143551	total: 1m 45s	remaining: 1.58s
# 9853:	learn: 0.6143551	total: 1m 45s	remaining: 1.57s
# 9854:	learn: 0.6143550	total: 1m 45s	remaining: 1.56s
# 9855:	learn: 0.6143550	total: 1m 45s	remaining: 1.54s
# 9856:	learn: 0.6143550	total: 1m 45s	remaining: 1.53s
# 9857:	learn: 0.6143550	total: 1m 45s	remaining: 1.52s
# 9858:	learn: 0.6143550	total: 1m 45s	remaining: 1.51s
# 9859:	learn: 0.6143550	total: 1m 45s	remaining: 1.5s
# 9860:	learn: 0.6143550	total: 1m 45s	remaining: 1.49s
# 9861:	learn: 0.6143550	total: 1m 45s	remaining: 1.48s
# 9862:	learn: 0.6143550	total: 1m 45s	remaining: 1.47s
# 9863:	learn: 0.6143550	total: 1m 45s	remaining: 1.46s
# 9864:	learn: 0.6143550	total: 1m 45s	remaining: 1.45s
# 9865:	learn: 0.6143549	total: 1m 45s	remaining: 1.44s
# 9866:	learn: 0.6143549	total: 1m 45s	remaining: 1.43s
# 9867:	learn: 0.6143548	total: 1m 45s	remaining: 1.42s
# 9868:	learn: 0.6143547	total: 1m 45s	remaining: 1.41s
# 9869:	learn: 0.6143547	total: 1m 45s	remaining: 1.4s
# 9870:	learn: 0.6143547	total: 1m 45s	remaining: 1.38s
# 9871:	learn: 0.6143547	total: 1m 45s	remaining: 1.37s
# 9872:	learn: 0.6143547	total: 1m 45s	remaining: 1.36s
# 9873:	learn: 0.6143547	total: 1m 45s	remaining: 1.35s
# 9874:	learn: 0.6143547	total: 1m 45s	remaining: 1.34s
# 9875:	learn: 0.6143547	total: 1m 45s	remaining: 1.33s
# 9876:	learn: 0.6143547	total: 1m 45s	remaining: 1.32s
# 9877:	learn: 0.6143547	total: 1m 46s	remaining: 1.31s
# 9878:	learn: 0.6143545	total: 1m 46s	remaining: 1.3s
# 9879:	learn: 0.6143545	total: 1m 46s	remaining: 1.29s
# 9880:	learn: 0.6143545	total: 1m 46s	remaining: 1.28s
# 9881:	learn: 0.6143544	total: 1m 46s	remaining: 1.27s
# 9882:	learn: 0.6143544	total: 1m 46s	remaining: 1.25s
# 9883:	learn: 0.6143544	total: 1m 46s	remaining: 1.24s
# 9884:	learn: 0.6143543	total: 1m 46s	remaining: 1.23s
# 9885:	learn: 0.6143543	total: 1m 46s	remaining: 1.22s
# 9886:	learn: 0.6143543	total: 1m 46s	remaining: 1.21s
# 9887:	learn: 0.6143542	total: 1m 46s	remaining: 1.2s
# 9888:	learn: 0.6143542	total: 1m 46s	remaining: 1.19s
# 9889:	learn: 0.6143541	total: 1m 46s	remaining: 1.18s
# 9890:	learn: 0.6143541	total: 1m 46s	remaining: 1.17s
# 9891:	learn: 0.6143541	total: 1m 46s	remaining: 1.16s
# 9892:	learn: 0.6143541	total: 1m 46s	remaining: 1.15s
# 9893:	learn: 0.6143541	total: 1m 46s	remaining: 1.14s
# 9894:	learn: 0.6143540	total: 1m 46s	remaining: 1.13s
# 9895:	learn: 0.6143540	total: 1m 46s	remaining: 1.12s
# 9896:	learn: 0.6143540	total: 1m 46s	remaining: 1.1s
# 9897:	learn: 0.6143540	total: 1m 46s	remaining: 1.09s
# 9898:	learn: 0.6143540	total: 1m 46s	remaining: 1.08s
# 9899:	learn: 0.6143540	total: 1m 46s	remaining: 1.07s
# 9900:	learn: 0.6143540	total: 1m 46s	remaining: 1.06s
# 9901:	learn: 0.6143540	total: 1m 46s	remaining: 1.05s
# 9902:	learn: 0.6143540	total: 1m 46s	remaining: 1.04s
# 9903:	learn: 0.6143540	total: 1m 46s	remaining: 1.03s
# 9904:	learn: 0.6143540	total: 1m 46s	remaining: 1.02s
# 9905:	learn: 0.6143540	total: 1m 46s	remaining: 1.01s
# 9906:	learn: 0.6143540	total: 1m 46s	remaining: 998ms
# 9907:	learn: 0.6143540	total: 1m 46s	remaining: 987ms
# 9908:	learn: 0.6143540	total: 1m 46s	remaining: 976ms
# 9909:	learn: 0.6143540	total: 1m 46s	remaining: 966ms
# 9910:	learn: 0.6143540	total: 1m 46s	remaining: 955ms
# 9911:	learn: 0.6143540	total: 1m 46s	remaining: 944ms
# 9912:	learn: 0.6143539	total: 1m 46s	remaining: 933ms
# 9913:	learn: 0.6143539	total: 1m 46s	remaining: 923ms
# 9914:	learn: 0.6143539	total: 1m 46s	remaining: 912ms
# 9915:	learn: 0.6143539	total: 1m 46s	remaining: 901ms
# 9916:	learn: 0.6143539	total: 1m 46s	remaining: 891ms
# 9917:	learn: 0.6143539	total: 1m 46s	remaining: 880ms
# 9918:	learn: 0.6143538	total: 1m 46s	remaining: 869ms
# 9919:	learn: 0.6143538	total: 1m 46s	remaining: 858ms
# 9920:	learn: 0.6143538	total: 1m 46s	remaining: 848ms
# 9921:	learn: 0.6143537	total: 1m 46s	remaining: 837ms
# 9922:	learn: 0.6143537	total: 1m 46s	remaining: 826ms
# 9923:	learn: 0.6143537	total: 1m 46s	remaining: 815ms
# 9924:	learn: 0.6143536	total: 1m 46s	remaining: 805ms
# 9925:	learn: 0.6143536	total: 1m 46s	remaining: 794ms
# 9926:	learn: 0.6143535	total: 1m 46s	remaining: 783ms
# 9927:	learn: 0.6143535	total: 1m 46s	remaining: 773ms
# 9928:	learn: 0.6143535	total: 1m 46s	remaining: 762ms
# 9929:	learn: 0.6143535	total: 1m 46s	remaining: 751ms
# 9930:	learn: 0.6143534	total: 1m 46s	remaining: 740ms
# 9931:	learn: 0.6143533	total: 1m 46s	remaining: 730ms
# 9932:	learn: 0.6143533	total: 1m 46s	remaining: 719ms
# 9933:	learn: 0.6143533	total: 1m 46s	remaining: 708ms
# 9934:	learn: 0.6143533	total: 1m 46s	remaining: 697ms
# 9935:	learn: 0.6143533	total: 1m 46s	remaining: 687ms
# 9936:	learn: 0.6143532	total: 1m 46s	remaining: 676ms
# 9937:	learn: 0.6143532	total: 1m 46s	remaining: 665ms
# 9938:	learn: 0.6143532	total: 1m 46s	remaining: 655ms
# 9939:	learn: 0.6143532	total: 1m 46s	remaining: 644ms
# 9940:	learn: 0.6143532	total: 1m 46s	remaining: 633ms
# 9941:	learn: 0.6143531	total: 1m 46s	remaining: 622ms
# 9942:	learn: 0.6143530	total: 1m 46s	remaining: 612ms
# 9943:	learn: 0.6143530	total: 1m 46s	remaining: 601ms
# 9944:	learn: 0.6143530	total: 1m 46s	remaining: 590ms
# 9945:	learn: 0.6143530	total: 1m 46s	remaining: 579ms
# 9946:	learn: 0.6143529	total: 1m 46s	remaining: 569ms
# 9947:	learn: 0.6143528	total: 1m 46s	remaining: 558ms
# 9948:	learn: 0.6143527	total: 1m 46s	remaining: 547ms
# 9949:	learn: 0.6143527	total: 1m 46s	remaining: 536ms
# 9950:	learn: 0.6143527	total: 1m 46s	remaining: 526ms
# 9951:	learn: 0.6143527	total: 1m 46s	remaining: 515ms
# 9952:	learn: 0.6143527	total: 1m 46s	remaining: 504ms
# 9953:	learn: 0.6143527	total: 1m 46s	remaining: 494ms
# 9954:	learn: 0.6143527	total: 1m 46s	remaining: 483ms
# 9955:	learn: 0.6143527	total: 1m 46s	remaining: 472ms
# 9956:	learn: 0.6143527	total: 1m 46s	remaining: 461ms
# 9957:	learn: 0.6143526	total: 1m 46s	remaining: 451ms
# 9958:	learn: 0.6143526	total: 1m 46s	remaining: 440ms
# 9959:	learn: 0.6143526	total: 1m 46s	remaining: 429ms
# 9960:	learn: 0.6143526	total: 1m 46s	remaining: 418ms
# 9961:	learn: 0.6143525	total: 1m 46s	remaining: 408ms
# 9962:	learn: 0.6143525	total: 1m 46s	remaining: 397ms
# 9963:	learn: 0.6143524	total: 1m 46s	remaining: 386ms
# 9964:	learn: 0.6143524	total: 1m 46s	remaining: 376ms
# 9965:	learn: 0.6143524	total: 1m 46s	remaining: 365ms
# 9966:	learn: 0.6143524	total: 1m 46s	remaining: 354ms
# 9967:	learn: 0.6143524	total: 1m 46s	remaining: 343ms
# 9968:	learn: 0.6143524	total: 1m 46s	remaining: 333ms
# 9969:	learn: 0.6143524	total: 1m 46s	remaining: 322ms
# 9970:	learn: 0.6143524	total: 1m 46s	remaining: 311ms
# 9971:	learn: 0.6143523	total: 1m 46s	remaining: 300ms
# 9972:	learn: 0.6143523	total: 1m 47s	remaining: 290ms
# 9973:	learn: 0.6143523	total: 1m 47s	remaining: 279ms
# 9974:	learn: 0.6143523	total: 1m 47s	remaining: 268ms
# 9975:	learn: 0.6143523	total: 1m 47s	remaining: 257ms
# 9976:	learn: 0.6143522	total: 1m 47s	remaining: 247ms
# 9977:	learn: 0.6143521	total: 1m 47s	remaining: 236ms
# 9978:	learn: 0.6143521	total: 1m 47s	remaining: 225ms
# 9979:	learn: 0.6143521	total: 1m 47s	remaining: 215ms
# 9980:	learn: 0.6143521	total: 1m 47s	remaining: 204ms
# 9981:	learn: 0.6143521	total: 1m 47s	remaining: 193ms
# 9982:	learn: 0.6143520	total: 1m 47s	remaining: 182ms
# 9983:	learn: 0.6143519	total: 1m 47s	remaining: 172ms
# 9984:	learn: 0.6143519	total: 1m 47s	remaining: 161ms
# 9985:	learn: 0.6143519	total: 1m 47s	remaining: 150ms
# 9986:	learn: 0.6143519	total: 1m 47s	remaining: 139ms
# 9987:	learn: 0.6143519	total: 1m 47s	remaining: 129ms
# 9988:	learn: 0.6143518	total: 1m 47s	remaining: 118ms
# 9989:	learn: 0.6143517	total: 1m 47s	remaining: 107ms
# 9990:	learn: 0.6143517	total: 1m 47s	remaining: 96.6ms
# 9991:	learn: 0.6143517	total: 1m 47s	remaining: 85.8ms
# 9992:	learn: 0.6143512	total: 1m 47s	remaining: 75.1ms
# 9993:	learn: 0.6143512	total: 1m 47s	remaining: 64.4ms
# 9994:	learn: 0.6143512	total: 1m 47s	remaining: 53.6ms
# 9995:	learn: 0.6143512	total: 1m 47s	remaining: 42.9ms
# 9996:	learn: 0.6143512	total: 1m 47s	remaining: 32.2ms
# 9997:	learn: 0.6143512	total: 1m 47s	remaining: 21.5ms
# 9998:	learn: 0.6143512	total: 1m 47s	remaining: 10.7ms
# 9999:	learn: 0.6143511	total: 1m 47s	remaining: 0us
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 2
#       1 # Fit CatBoost
# ----> 2 cat_pipe.fit(X_train, y_train).head()
#
# AttributeError: 'TransformedTargetRegressor' object has no attribute 'head'

# %%
lin_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       LinearRegression())]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
ada_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       AdaBoostRegressor(learning_rate=0.01,
#                                                                         loss='exponential',
#                                                                         n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
extra_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       ExtraTreesRegressor(bootstrap=True,
#                                                                           criterion='friedman_mse',
#                                                                           n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %% [markdown]
# ## 05.Model Evaluation

# %% [markdown]
# 1.R2
#
# 2.RMSE(Root mean squared error)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

# %%
def generate_model_score(model, data, metric_function):
    X, y  = data
    y_ = model.predict(X)
    score = metric_function(y, y_)
    return score

# %%
def print_metrics(metric_name, train_score, test_score):
    print(f"Train{metric_name} = {train_score}")
    print(f"Test{metric_name} = {test_score}")
    print(f"Generalization error = {train_score - test_score}")
    
    return

# %%
def test_model(model, data, metric_name, metric_function):
    train, test = data
    
    if isinstance(metric_name, str):# Single metric
        train_score = generate_model_score(model, train, metric_function)
        test_score = generate_model_score(model, test, metric_function)
        print_metrics(metric_name, train_score, test_score)
        
    else:# Multiple metric
        for name, function in zip(metric_name, metric_function):
            train_score = generate_model_score(model, train, function)
            test_score = generate_model_score(model, test, function)
            print_metrics(name, train_score, test_score)
            
    return

# %%
#Name and function for metrics
metric_name = ["R2", "RMSE"]
metric_function = [r2_score, root_mean_squared_error]

# %%
#Create data variable
data_ = [
    [X_train,y_train],
    [X_test, y_test]
]

# %%
from sklearn.preprocessing import OrdinalEncoder
#Test CatBoost
test_model(cat_pipe, data_, metric_name, metric_function)
# Out:
# TrainR2 = 0.32853080438362303
# TestR2 = 0.3418724096228096
# Generalization error = -0.013341605239186594
# TrainRMSE = 373.49118810470225
# TestRMSE = 301.0651042861855
# Generalization error = 72.42608381851676

# %%
#Test Linear Regression
test_model(lin_pipe, data_, metric_name, metric_function)
# Out:
# TrainR2 = 0.06460931699130279
# TestR2 = 0.10270630059859631
# Generalization error = -0.03809698360729352
# TrainRMSE = 440.82258084034095
# TestRMSE = 351.53832622435266
# Generalization error = 89.28425461598829

# %%
#Test AdaBoost
test_model(ada_pipe, data_, metric_name, metric_function)
# Out:
# TrainR2 = 0.06712117773237902
# TestR2 = 0.0958239435774223
# Generalization error = -0.028702765845043277
# TrainRMSE = 440.23029928399654
# TestRMSE = 352.88392280905225
# Generalization error = 87.3463764749443

# %%
#Test ExtraTrees
test_model(extra_pipe, data_, metric_name, metric_function)
# Out:
# TrainR2 = 0.23086556276914938
# TestR2 = 0.20160167617469693
# Generalization error = 0.02926388659445245
# TrainRMSE = 399.7315627148886
# TestRMSE = 331.6005022948318
# Generalization error = 68.13106042005677

# %% [markdown]
# ## 6.Model Deployment

# %% [markdown]
# As observed from the Model Evaluation phase, although the CatBoost pipeline performed best amongst all the models,
# its scores were still quite bad(r2 score = 0.32)
#
# ## Recommendations:
# The company should find means of obtaining better, all encompassed dataset because the features were few,
# categorical in nature and had a lot of missing data.
